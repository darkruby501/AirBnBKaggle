# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Draw inline
# %matplotlib inline

# Set figure aesthetics
sns.set_style("white", {'ytick.major.size': 10.0})
sns.set_context("poster", font_scale=1.1)
# Out:
# c:\Anaconda3\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Date Cleaning
# ## Fix Missing or Abberant Values
#
# 1) Detect missing and abberant.
# 2) Replace/impute
#
# Pieces borrowed from: https://www.kaggle.com/davidgasquez/airbnb-recruiting-new-user-bookings/user-data-exploration

# %%
# Load data into DataFrames
train_users = pd.read_csv('input/train_users_2.csv')
test_users = pd.read_csv('input/test_users.csv')

# %%
print("We have", train_users.shape[0], "users in the training set and", 
      test_users.shape[0], "in the test set.")
print("In total we have", train_users.shape[0] + test_users.shape[0], "users.")
# Out:
# We have 213451 users in the training set and 62096 in the test set.
# In total we have 275547 users.

# %%
# Save Train Length for Splitting
piv_train = train_users.shape[0]

# %%
# Merge train and test users
users = pd.concat((train_users, test_users), axis=0, ignore_index=True)

# Remove ID's since now we are not interested in making predictions
#users.drop('id',axis=1, inplace=True)

users.head()
# Out:
#   affiliate_channel affiliate_provider  age country_destination  \
# 0            direct             direct  NaN                 NDF
# 1               seo             google   38                 NDF
# 2            direct             direct   56                  US
# 3            direct             direct   42               other
# 4            direct             direct   41                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type     gender language signup_app  signup_flow  \
# 0        Chrome       Mac Desktop  -unknown-       en        Web            0
# 1        Chrome       Mac Desktop       MALE       en        Web            0
# 2            IE   Windows Desktop     FEMALE       en        Web            3
# 3       Firefox       Mac Desktop     FEMALE       en        Web            0
# 4        Chrome       Mac Desktop  -unknown-       en        Web            0
#
#   signup_method  timestamp_first_active
# 0      facebook          20090319043255
# 1      facebook          20090523174809
# 2         basic          20090609231247
# 3      facebook          20091031060129
# 4         basic          20091208061105

# %%
## Replace All Missing Values with Nan
users['gender'].replace('-unknown-',np.nan, inplace=True)
users['first_affiliate_tracked'].replace('',np.nan, inplace=True)

# %% [markdown]
# ## How much is missing?

# %%
## Examing how much data is missing

users_nan = (users.isnull().sum() / users.shape[0]) * 100
users_nan[users_nan > 0].drop('country_destination')
# Out:
# date_first_booking    67.733998
# dtype: float64

# %%
## Is newer data better? -- NO
test_users['gender'].replace('-unknown-',np.nan, inplace=True)
users_nan = (test_users.isnull().sum() / test_users.shape[0]) * 100
users_nan[users_nan > 0]
# Out:
# date_first_booking         100.000000
# gender                      54.418964
# age                         46.502190
# first_affiliate_tracked      0.032208
# dtype: float64

# %%
# Gender in test users
test_users['gender'].value_counts(dropna=False)
# Out:
# NaN       33792
# FEMALE    14483
# MALE      13769
# OTHER        52
# Name: gender, dtype: int64

# %% [markdown]
# Quite a lot missing in Age and Gender.
# Some missing in first_affilate_tracked

# %% [markdown]
# ### Age

# %%
users['age'].describe()
# Out:
# count    155825.000000
# mean         36.012418
# std          11.553568
# min          15.000000
# 25%          28.000000
# 50%          33.000000
# 75%          42.000000
# max          95.000000
# Name: age, dtype: float64

# %%
users.loc[users.age > 95, 'age'] = np.nan
users.loc[users.age < 13, 'age'] = np.nan

# %% [markdown]
# ### Gender

# %%
users['gender'].value_counts(dropna=False)
# Out:
# NaN       129480
# FEMALE     77524
# MALE       68209
# OTHER        334
# dtype: int64

# %% [markdown]
# ### First Affiliate Tracked

# %%
users['first_affiliate_tracked'].value_counts(dropna=False)
# Out:
# untracked        143181
# linked            62064
# omg               54859
# tracked-other      6655
# NaN                6085
# product            2353
# marketing           281
# local ops            69
# dtype: int64

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# # IMPUTATION / REPLACING VALUES

# %% [markdown]
# ### Age

# %%
users['age'].fillna(-1,inplace=True)

# %% [markdown]
# ### Gender

# %%
users['gender'].cat.add_categories('MISSING',inplace=True)
users['gender'].fillna('MISSING',inplace=True)

# %% [markdown]
# ### First Affiliate Tracked

# %%
users['first_affiliate_tracked'].fillna('untracked',inplace=True)

# %% [markdown]
# # COMBINED PROCESSING

# %%
## AGE

# Replace Out of Range Values
train_users.loc[train_users.age > 95, 'age'] = -1
train_users.loc[train_users.age < 13, 'age'] = -1
train_users.fillna(-1,inplace=True)

## GENDER
train_users.fillna('MISSING',inplace=True)

## FIRST AFFILIATE TRACKED
train_users['first_affiliate_tracked'].fillna('untracked',inplace=True)

# %%
def preprocess_users(df):
    ##AGE
    df.loc[df.age > 95, 'age'] = -1
    df.loc[df.age < 13, 'age'] = -1
    df.fillna(-1,inplace=True)

    ## GENDER
    df.fillna('MISSING',inplace=True)

    ## FIRST AFFILIATE TRACKED
    df['first_affiliate_tracked'].fillna('untracked',inplace=True)
    
    return df

# %%
A = preprocess_users(train_users)

# %%
A.equals(train_users)
# Out:
# True

# %%
users.head(100)
# Out:
#    affiliate_channel affiliate_provider  age country_destination  \
# 0             direct             direct   -1                 NDF
# 1                seo             google   38                 NDF
# 2             direct             direct   56                  US
# 3             direct             direct   42               other
# 4             direct             direct   41                  US
# 5              other              other   -1                  US
# 6              other         craigslist   46                  US
# 7             direct             direct   47                  US
# 8              other         craigslist   50                  US
# 9              other         craigslist   46                  US
# 10             other         craigslist   36                  US
# 11             other         craigslist   47                 NDF
# 12            direct             direct   -1                  FR
# 13             other         craigslist   37                 NDF
# 14             other         craigslist   36                 NDF
# 15            direct             direct   33                  CA
# 16             other         craigslist   -1                 NDF
# 17             other         craigslist   31                  US
# 18               seo           facebook   -1                 NDF
# 19            direct             direct   29                  FR
# 20            direct             direct   -1                  US
# 21            direct             direct   30                  US
# 22               seo             google   40                  US
# 23             other         craigslist   -1                 NDF
# 24               seo             google   40                 NDF
# 25             other         craigslist   26                  FR
# 26             other              other   -1                 NDF
# 27             other         craigslist   32                  US
# 28            direct             direct   35                  FR
# 29            direct             direct   37                  US
# ..               ...                ...  ...                 ...
# 70             other              other   -1                  US
# 71               seo             google   31                 NDF
# 72             other         craigslist   29                 NDF
# 73             other         craigslist   -1                 NDF
# 74             other         craigslist   57                  FR
# 75            direct             direct   30                  US
# 76             other         craigslist   49                  US
# 77             other         craigslist   37                 NDF
# 78            direct             direct   -1                  GB
# 79             other         craigslist   26                 NDF
# 80             other              other   -1               other
# 81             other         craigslist   36                  US
# 82            direct             direct   -1                 NDF
# 83             other         craigslist   -1                 NDF
# 84             other         craigslist   32                  US
# 85            direct             direct   33                  US
# 86             other         craigslist   46                  US
# 87            direct             direct   40                  IT
# 88             other         craigslist   25                 NDF
# 89             other              other   25                 NDF
# 90             other         craigslist   54                  FR
# 91            direct             direct   32                  US
# 92             other         craigslist   -1                  FR
# 93               seo             google   28                  US
# 94             other         craigslist   57                  US
# 95             other         craigslist   47                  US
# 96            direct             direct   34                  US
# 97             other         craigslist   -1                  US
# 98             other         craigslist   35                 NDF
# 99     sem-non-brand              other   32                 NDF
#
#    date_account_created date_first_booking first_affiliate_tracked  \
# 0            2010-06-28                NaN               untracked
# 1            2011-05-25                NaN               untracked
# 2            2010-09-28         2010-08-02               untracked
# 3            2011-12-05         2012-09-08               untracked
# 4            2010-09-14         2010-02-18               untracked
# 5            2010-01-01         2010-01-02                     omg
# 6            2010-01-02         2010-01-05               untracked
# 7            2010-01-03         2010-01-13                     omg
# 8            2010-01-04         2010-07-29               untracked
# 9            2010-01-04         2010-01-04                     omg
# 10           2010-01-04         2010-01-06               untracked
# 11           2010-01-05                NaN               untracked
# 12           2010-01-05         2010-01-18               untracked
# 13           2010-01-05                NaN                  linked
# 14           2010-01-07                NaN               untracked
# 15           2010-01-07         2010-01-08               untracked
# 16           2010-01-07                NaN               untracked
# 17           2010-01-07         2010-01-09               untracked
# 18           2010-01-08                NaN               untracked
# 19           2010-01-10         2010-01-10               untracked
# 20           2010-01-10         2010-01-18               untracked
# 21           2010-01-10         2010-01-11                  linked
# 22           2010-01-11         2010-01-11               untracked
# 23           2010-01-11                NaN               untracked
# 24           2010-01-11                NaN               untracked
# 25           2010-01-12         2010-01-15               untracked
# 26           2010-01-12                NaN               untracked
# 27           2010-01-12         2010-01-22               untracked
# 28           2010-01-13         2010-01-13               untracked
# 29           2010-01-13         2010-01-19               untracked
# ..                  ...                ...                     ...
# 70           2010-02-02         2010-02-02               untracked
# 71           2010-02-02                NaN                  linked
# 72           2010-02-02                NaN                     omg
# 73           2010-02-02                NaN               untracked
# 74           2010-02-02         2010-02-09                     omg
# 75           2010-02-03         2010-02-04               untracked
# 76           2010-02-03         2010-08-12               untracked
# 77           2010-02-04                NaN                     omg
# 78           2010-02-04         2010-03-20               untracked
# 79           2010-02-06                NaN           tracked-other
# 80           2010-02-06         2010-02-06               untracked
# 81           2010-02-06         2010-02-10               untracked
# 82           2010-02-06                NaN               untracked
# 83           2010-02-06                NaN                  linked
# 84           2010-02-07         2010-02-07                  linked
# 85           2010-02-07         2010-06-01               untracked
# 86           2010-02-08         2010-02-11               untracked
# 87           2010-02-08         2010-02-26                  linked
# 88           2010-02-09                NaN                  linked
# 89           2010-02-09                NaN                     omg
# 90           2010-02-09         2010-02-20               untracked
# 91           2010-02-09         2010-02-10               untracked
# 92           2010-02-10         2010-03-19               untracked
# 93           2010-02-10         2010-08-25                  linked
# 94           2010-02-10         2010-02-12           tracked-other
# 95           2010-02-10         2010-02-13                  linked
# 96           2010-02-10         2010-07-16                  linked
# 97           2010-02-11         2010-02-13               untracked
# 98           2010-02-11                NaN               untracked
# 99           2010-02-11                NaN               untracked
#
#     first_browser first_device_type   gender language signup_app signup_flow  \
# 0          Chrome       Mac Desktop  MISSING       en        Web           0
# 1          Chrome       Mac Desktop     MALE       en        Web           0
# 2              IE   Windows Desktop   FEMALE       en        Web           3
# 3         Firefox       Mac Desktop   FEMALE       en        Web           0
# 4          Chrome       Mac Desktop  MISSING       en        Web           0
# 5          Chrome       Mac Desktop  MISSING       en        Web           0
# 6          Safari       Mac Desktop   FEMALE       en        Web           0
# 7          Safari       Mac Desktop   FEMALE       en        Web           0
# 8          Safari       Mac Desktop   FEMALE       en        Web           0
# 9         Firefox       Mac Desktop  MISSING       en        Web           0
# 10        Firefox       Mac Desktop   FEMALE       en        Web           0
# 11      -unknown-            iPhone   FEMALE       en        Web           0
# 12      -unknown-     Other/Unknown  MISSING       en        Web           0
# 13        Firefox       Mac Desktop   FEMALE       en        Web           0
# 14  Mobile Safari            iPhone   FEMALE       en        Web           0
# 15         Chrome   Windows Desktop   FEMALE       en        Web           0
# 16      -unknown-     Other/Unknown  MISSING       en        Web           0
# 17      -unknown-     Other/Unknown  MISSING       en        Web           0
# 18      -unknown-     Other/Unknown  MISSING       en        Web           0
# 19         Chrome       Mac Desktop   FEMALE       en        Web           0
# 20      -unknown-     Other/Unknown  MISSING       en        Web           0
# 21         Chrome       Mac Desktop     MALE       en        Web           0
# 22      -unknown-            iPhone  MISSING       en        Web           0
# 23         Safari       Mac Desktop  MISSING       en        Web           0
# 24        Firefox       Mac Desktop   FEMALE       en        Web           0
# 25         Chrome       Mac Desktop   FEMALE       en        Web           0
# 26      -unknown-     Other/Unknown  MISSING       en        Web           0
# 27         Chrome   Desktop (Other)   FEMALE       en        Web           0
# 28      -unknown-     Other/Unknown  MISSING       en        Web           0
# 29      -unknown-    Android Tablet  MISSING       en        Web           0
# ..            ...               ...      ...      ...        ...         ...
# 70      -unknown-     Other/Unknown  MISSING       en        Web           0
# 71         Safari       Mac Desktop   FEMALE       en        Web           0
# 72         Safari       Mac Desktop  MISSING       en        Web           0
# 73      -unknown-     Other/Unknown  MISSING       en        Web           0
# 74        Firefox   Windows Desktop   FEMALE       en        Web           0
# 75         Chrome       Mac Desktop   FEMALE       en        Web           0
# 76         Chrome       Mac Desktop  MISSING       en        Web           0
# 77         Safari       Mac Desktop   FEMALE       en        Web           0
# 78      -unknown-            iPhone  MISSING       en        Web           0
# 79  Mobile Safari            iPhone  MISSING       en        Web           0
# 80      -unknown-     Other/Unknown  MISSING       en        Web           3
# 81      -unknown-            iPhone   FEMALE       en        Web           2
# 82         Chrome       Mac Desktop  MISSING       en        Web           3
# 83         Chrome       Mac Desktop  MISSING       en        Web           2
# 84         Chrome   Windows Desktop   FEMALE       en        Web           0
# 85        Firefox       Mac Desktop     MALE       en        Web           2
# 86             IE   Windows Desktop   FEMALE       en        Web           2
# 87        Firefox       Mac Desktop   FEMALE       en        Web           2
# 88         Chrome       Mac Desktop     MALE       en        Web           2
# 89         Chrome       Mac Desktop     MALE       en        Web           2
# 90         Safari       Mac Desktop  MISSING       en        Web           2
# 91         Chrome       Mac Desktop  MISSING       en        Web           2
# 92         Safari       Mac Desktop  MISSING       en        Web           3
# 93         Chrome   Windows Desktop  MISSING       en        Web           2
# 94        Firefox       Mac Desktop   FEMALE       en        Web           2
# 95             IE   Windows Desktop   FEMALE       en        Web           3
# 96         Chrome   Windows Desktop     MALE       en        Web           0
# 97      -unknown-     Other/Unknown  MISSING       en        Web           3
# 98      -unknown-     Other/Unknown  MISSING       en        Web           2
# 99         Chrome   Windows Desktop  MISSING       en        Web           2
#
#    signup_method  timestamp_first_active
# 0       facebook          20090319043255
# 1       facebook          20090523174809
# 2          basic          20090609231247
# 3       facebook          20091031060129
# 4          basic          20091208061105
# 5          basic          20100101215619
# 6          basic          20100102012558
# 7          basic          20100103191905
# 8          basic          20100104004211
# 9          basic          20100104023758
# 10         basic          20100104194251
# 11         basic          20100105051812
# 12         basic          20100105060859
# 13         basic          20100105083259
# 14         basic          20100107055820
# 15         basic          20100107204555
# 16         basic          20100107215125
# 17         basic          20100107224625
# 18         basic          20100108015641
# 19         basic          20100110010817
# 20         basic          20100110152120
# 21         basic          20100110220941
# 22         basic          20100111031438
# 23         basic          20100111224015
# 24         basic          20100111230808
# 25         basic          20100112131444
# 26         basic          20100112155420
# 27         basic          20100112205949
# 28         basic          20100113044650
# 29         basic          20100113064333
# ..           ...                     ...
# 70         basic          20100202050231
# 71         basic          20100202085002
# 72         basic          20100202170603
# 73         basic          20100202180421
# 74         basic          20100202223117
# 75         basic          20100203000944
# 76         basic          20100203225854
# 77         basic          20100204005644
# 78         basic          20100204180032
# 79         basic          20100206012446
# 80         basic          20100206070403
# 81         basic          20100206072233
# 82         basic          20100206155410
# 83         basic          20100206163608
# 84         basic          20100207014229
# 85         basic          20100207015207
# 86      facebook          20100208191612
# 87         basic          20100208214250
# 88      facebook          20100209014007
# 89      facebook          20100209062147
# 90         basic          20100209064317
# 91      facebook          20100209070009
# 92         basic          20100210024029
# 93         basic          20100210045352
# 94         basic          20100210050927
# 95         basic          20100210082803
# 96         basic          20100210231137
# 97         basic          20100211030330
# 98         basic          20100211100737
# 99         basic          20100211121538
#
# [100 rows x 15 columns]

# %%
import preprocess_clean

# %%
preprocess_users
# Out:
# <function __main__.preprocess_users>

# %%
## Encode catogorical features as categories

categorical_features = [
    'affiliate_channel',
    'affiliate_provider',
    'country_destination',
    'first_affiliate_tracked',
    'first_browser',
    'first_device_type',
    'gender',
    'language',
    'signup_app',
    'signup_flow',
    'signup_method'
]

for categorical_feature in categorical_features:
    users[categorical_feature] = users[categorical_feature].astype('category')

# %%
users
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 0                 direct             direct  NaN                 NDF
# 1                    seo             google   38                 NDF
# 2                 direct             direct   56                  US
# 3                 direct             direct   42               other
# 4                 direct             direct   41                  US
# 5                  other              other  NaN                  US
# 6                  other         craigslist   46                  US
# 7                 direct             direct   47                  US
# 8                  other         craigslist   50                  US
# 9                  other         craigslist   46                  US
# 10                 other         craigslist   36                  US
# 11                 other         craigslist   47                 NDF
# 12                direct             direct  NaN                  FR
# 13                 other         craigslist   37                 NDF
# 14                 other         craigslist   36                 NDF
# 15                direct             direct   33                  CA
# 16                 other         craigslist  NaN                 NDF
# 17                 other         craigslist   31                  US
# 18                   seo           facebook  NaN                 NDF
# 19                direct             direct   29                  FR
# 20                direct             direct  NaN                  US
# 21                direct             direct   30                  US
# 22                   seo             google   40                  US
# 23                 other         craigslist  NaN                 NDF
# 24                   seo             google   40                 NDF
# 25                 other         craigslist   26                  FR
# 26                 other              other  NaN                 NDF
# 27                 other         craigslist   32                  US
# 28                direct             direct   35                  FR
# 29                direct             direct   37                  US
# ...                  ...                ...  ...                 ...
# 275517            direct             direct  NaN                 NaN
# 275518            direct             direct   48                 NaN
# 275519               seo             google  NaN                 NaN
# 275520            direct             direct   24                 NaN
# 275521               seo           facebook   32                 NaN
# 275522            direct             direct  NaN                 NaN
# 275523            direct             direct  NaN                 NaN
# 275524            direct             direct  NaN                 NaN
# 275525            direct             direct  NaN                 NaN
# 275526         sem-brand             google   40                 NaN
# 275527               seo           facebook   39                 NaN
# 275528               seo             google  NaN                 NaN
# 275529               seo             google  NaN                 NaN
# 275530               seo             google   44                 NaN
# 275531               seo             google   39                 NaN
# 275532            direct             direct   34                 NaN
# 275533               seo             google  NaN                 NaN
# 275534            direct             direct   40                 NaN
# 275535            direct             direct   27                 NaN
# 275536            direct             direct   24                 NaN
# 275537            direct             direct  NaN                 NaN
# 275538         sem-brand             google   55                 NaN
# 275539            direct             direct   34                 NaN
# 275540            direct             direct   32                 NaN
# 275541               seo              yahoo  NaN                 NaN
# 275542            direct             direct   31                 NaN
# 275543            direct             direct  NaN                 NaN
# 275544            direct             direct  NaN                 NaN
# 275545         sem-brand             google  NaN                 NaN
# 275546             other              other   49                 NaN
#
#        date_account_created date_first_booking first_affiliate_tracked  \
# 0                2010-06-28                NaN               untracked
# 1                2011-05-25                NaN               untracked
# 2                2010-09-28         2010-08-02               untracked
# 3                2011-12-05         2012-09-08               untracked
# 4                2010-09-14         2010-02-18               untracked
# 5                2010-01-01         2010-01-02                     omg
# 6                2010-01-02         2010-01-05               untracked
# 7                2010-01-03         2010-01-13                     omg
# 8                2010-01-04         2010-07-29               untracked
# 9                2010-01-04         2010-01-04                     omg
# 10               2010-01-04         2010-01-06               untracked
# 11               2010-01-05                NaN               untracked
# 12               2010-01-05         2010-01-18                     NaN
# 13               2010-01-05                NaN                  linked
# 14               2010-01-07                NaN               untracked
# 15               2010-01-07         2010-01-08               untracked
# 16               2010-01-07                NaN                     NaN
# 17               2010-01-07         2010-01-09                     NaN
# 18               2010-01-08                NaN                     NaN
# 19               2010-01-10         2010-01-10               untracked
# 20               2010-01-10         2010-01-18                     NaN
# 21               2010-01-10         2010-01-11                  linked
# 22               2010-01-11         2010-01-11               untracked
# 23               2010-01-11                NaN               untracked
# 24               2010-01-11                NaN               untracked
# 25               2010-01-12         2010-01-15               untracked
# 26               2010-01-12                NaN               untracked
# 27               2010-01-12         2010-01-22               untracked
# 28               2010-01-13         2010-01-13                     NaN
# 29               2010-01-13         2010-01-19               untracked
# ...                     ...                ...                     ...
# 275517           2014-09-30                NaN               untracked
# 275518           2014-09-30                NaN               untracked
# 275519           2014-09-30                NaN               untracked
# 275520           2014-09-30                NaN               untracked
# 275521           2014-09-30                NaN               untracked
# 275522           2014-09-30                NaN               untracked
# 275523           2014-09-30                NaN               untracked
# 275524           2014-09-30                NaN               untracked
# 275525           2014-09-30                NaN                  linked
# 275526           2014-09-30                NaN                     omg
# 275527           2014-09-30                NaN               untracked
# 275528           2014-09-30                NaN               untracked
# 275529           2014-09-30                NaN               untracked
# 275530           2014-09-30                NaN                  linked
# 275531           2014-09-30                NaN                  linked
# 275532           2014-09-30                NaN               untracked
# 275533           2014-09-30                NaN               untracked
# 275534           2014-09-30                NaN               untracked
# 275535           2014-09-30                NaN               untracked
# 275536           2014-09-30                NaN                  linked
# 275537           2014-09-30                NaN               untracked
# 275538           2014-09-30                NaN                     omg
# 275539           2014-09-30                NaN               untracked
# 275540           2014-09-30                NaN                  linked
# 275541           2014-09-30                NaN                  linked
# 275542           2014-09-30                NaN               untracked
# 275543           2014-09-30                NaN               untracked
# 275544           2014-09-30                NaN                  linked
# 275545           2014-09-30                NaN                     omg
# 275546           2014-09-30                NaN           tracked-other
#
#         first_browser first_device_type  gender language signup_app  \
# 0              Chrome       Mac Desktop     NaN       en        Web
# 1              Chrome       Mac Desktop    MALE       en        Web
# 2                  IE   Windows Desktop  FEMALE       en        Web
# 3             Firefox       Mac Desktop  FEMALE       en        Web
# 4              Chrome       Mac Desktop     NaN       en        Web
# 5              Chrome       Mac Desktop     NaN       en        Web
# 6              Safari       Mac Desktop  FEMALE       en        Web
# 7              Safari       Mac Desktop  FEMALE       en        Web
# 8              Safari       Mac Desktop  FEMALE       en        Web
# 9             Firefox       Mac Desktop     NaN       en        Web
# 10            Firefox       Mac Desktop  FEMALE       en        Web
# 11          -unknown-            iPhone  FEMALE       en        Web
# 12          -unknown-     Other/Unknown     NaN       en        Web
# 13            Firefox       Mac Desktop  FEMALE       en        Web
# 14      Mobile Safari            iPhone  FEMALE       en        Web
# 15             Chrome   Windows Desktop  FEMALE       en        Web
# 16          -unknown-     Other/Unknown     NaN       en        Web
# 17          -unknown-     Other/Unknown     NaN       en        Web
# 18          -unknown-     Other/Unknown     NaN       en        Web
# 19             Chrome       Mac Desktop  FEMALE       en        Web
# 20          -unknown-     Other/Unknown     NaN       en        Web
# 21             Chrome       Mac Desktop    MALE       en        Web
# 22          -unknown-            iPhone     NaN       en        Web
# 23             Safari       Mac Desktop     NaN       en        Web
# 24            Firefox       Mac Desktop  FEMALE       en        Web
# 25             Chrome       Mac Desktop  FEMALE       en        Web
# 26          -unknown-     Other/Unknown     NaN       en        Web
# 27             Chrome   Desktop (Other)  FEMALE       en        Web
# 28          -unknown-     Other/Unknown     NaN       en        Web
# 29          -unknown-    Android Tablet     NaN       en        Web
# ...               ...               ...     ...      ...        ...
# 275517      -unknown-     Android Phone     NaN       en    Android
# 275518         Safari       Mac Desktop  FEMALE       en        Web
# 275519        Firefox       Mac Desktop     NaN       en        Web
# 275520      -unknown-            iPhone  FEMALE       en        iOS
# 275521  Mobile Safari              iPad  FEMALE       en        Web
# 275522  Chrome Mobile     Android Phone     NaN       en      Moweb
# 275523      -unknown-     Android Phone     NaN       en    Android
# 275524      -unknown-     Android Phone     NaN       en    Android
# 275525  Mobile Safari            iPhone     NaN       en      Moweb
# 275526        Firefox   Windows Desktop  FEMALE       en        Web
# 275527  Mobile Safari            iPhone    MALE       en        Web
# 275528        Firefox       Mac Desktop     NaN       en        Web
# 275529  Mobile Safari              iPad     NaN       en        Web
# 275530         Chrome       Mac Desktop    MALE       en        Web
# 275531        Firefox   Windows Desktop     NaN       en        Web
# 275532      -unknown-     Android Phone  FEMALE       en    Android
# 275533         Safari       Mac Desktop     NaN       en        Web
# 275534      -unknown-     Android Phone    MALE       en    Android
# 275535        Firefox       Mac Desktop    MALE       en        Web
# 275536  Mobile Safari            iPhone  FEMALE       en        Web
# 275537      -unknown-            iPhone     NaN       en        iOS
# 275538        Firefox   Windows Desktop    MALE       en        Web
# 275539         Chrome       Mac Desktop     NaN       en        Web
# 275540         Chrome   Windows Desktop    MALE       en        Web
# 275541         Chrome   Windows Desktop     NaN       en        Web
# 275542             IE   Windows Desktop     NaN       en        Web
# 275543      -unknown-     Android Phone     NaN       ko    Android
# 275544        Firefox   Windows Desktop     NaN       de        Web
# 275545         Safari       Mac Desktop     NaN       en        Web
# 275546         Chrome   Windows Desktop  FEMALE       en        Web
#
#        signup_flow signup_method  timestamp_first_active
# 0                0      facebook          20090319043255
# 1                0      facebook          20090523174809
# 2                3         basic          20090609231247
# 3                0      facebook          20091031060129
# 4                0         basic          20091208061105
# 5                0         basic          20100101215619
# 6                0         basic          20100102012558
# 7                0         basic          20100103191905
# 8                0         basic          20100104004211
# 9                0         basic          20100104023758
# 10               0         basic          20100104194251
# 11               0         basic          20100105051812
# 12               0         basic          20100105060859
# 13               0         basic          20100105083259
# 14               0         basic          20100107055820
# 15               0         basic          20100107204555
# 16               0         basic          20100107215125
# 17               0         basic          20100107224625
# 18               0         basic          20100108015641
# 19               0         basic          20100110010817
# 20               0         basic          20100110152120
# 21               0         basic          20100110220941
# 22               0         basic          20100111031438
# 23               0         basic          20100111224015
# 24               0         basic          20100111230808
# 25               0         basic          20100112131444
# 26               0         basic          20100112155420
# 27               0         basic          20100112205949
# 28               0         basic          20100113044650
# 29               0         basic          20100113064333
# ...            ...           ...                     ...
# 275517          12        google          20140930231454
# 275518           0         basic          20140930231518
# 275519           0         basic          20140930231952
# 275520          25      facebook          20140930232126
# 275521           0      facebook          20140930232237
# 275522           0         basic          20140930232253
# 275523          23         basic          20140930232331
# 275524          23         basic          20140930232507
# 275525           0         basic          20140930232551
# 275526           0      facebook          20140930232613
# 275527           0      facebook          20140930233113
# 275528           0         basic          20140930233305
# 275529           0         basic          20140930233535
# 275530           0         basic          20140930233902
# 275531           0         basic          20140930234128
# 275532          23      facebook          20140930234425
# 275533           0         basic          20140930234515
# 275534          23      facebook          20140930234551
# 275535           0      facebook          20140930234612
# 275536           0      facebook          20140930234617
# 275537          25         basic          20140930234703
# 275538           0         basic          20140930234751
# 275539           0         basic          20140930234904
# 275540           0         basic          20140930235000
# 275541           0         basic          20140930235019
# 275542           0         basic          20140930235232
# 275543          23         basic          20140930235306
# 275544           0         basic          20140930235408
# 275545           0         basic          20140930235430
# 275546           0         basic          20140930235901
#
# [275547 rows x 15 columns]

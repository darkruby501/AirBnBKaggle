# %% [markdown]
# ## CLASSIFYING USING SESSION DEVICE TYPE
# ### Starting with Random Forest

# %%
# Imports

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# c:\Anaconda3\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# Import Data
airbnb_df  = pd.read_csv('input/train_users_2.csv',usecols=['id','country_destination'])
session_df = pd.read_csv('input/sessions.csv')

# %%
#Clean Data
session_df['secs_elapsed'].fillna(0,inplace=True)

# %%
session_df['action_type'].fillna('',inplace=True)
session_df['action_action_type'] = session_df['action']+'__'+session_df['action_type']

# %%
session_df.columns
# Out:
# Index(['user_id', 'action', 'action_type', 'action_detail', 'device_type',
#        'secs_elapsed', 'action_action_type'],
#       dtype='object')

# %%
session_devices = session_df[['user_id','device_type','secs_elapsed']]

# %%
A = session_devices.groupby(['user_id','device_type']).sum() 
A
# Out:
#                                              secs_elapsed
# user_id    device_type
# 00023iyk9l Mac Desktop                             295642
#            iPhone                                  572254
# 0010k6l0om Mac Desktop                             586543
# 001wyh0pz8 Android App Unknown Phone/Tablet        282965
# 0028jgx1x1 -unknown-                               297010
#            Android Phone                                0
# 002qnbzfs5 -unknown-                               203511
#            iPhone                                 6283569
# 0031awlkjq iPhone                                   39574
# 0035hobuyj Mac Desktop                            5724670
# 00378ocvlh Mac Desktop                            1827164
# 00389675gq Android Phone                           236259
#            Windows Desktop                        2369452
# 003iamz20l iPad Tablet                            1590236
# 0048rkdgb1 iPhone                                  329852
# 0057snrdpu Android Phone                             4268
#            iPhone                                 1319190
# 005jc3nbmb Windows Desktop                         994093
#            iPhone                                 1799852
# 005v5uf4dh iPhone                                  177779
# 0063bawn05 Mac Desktop                            2978016
# 006ml14zc1 Mac Desktop                             204263
# 006mls2sjw Mac Desktop                            2424268
# 006t3vhawl iPad Tablet                             815416
# 006z8b0uws Android Phone                           234868
#            Mac Desktop                              89354
# 0075z9e9xv Mac Desktop                            3501123
#            Windows Desktop                          85853
# 007gj7kqdk Windows Desktop                         370406
# 009a40t3dk -unknown-                                53709
# ...                                                   ...
# zzt5gpsyqa Mac Desktop                             878825
#            iPhone                                  354462
# zzt8w28nl5 Mac Desktop                            1083981
#            Windows Desktop                        1010968
# zztaeo9wd5 -unknown-                               670646
#            iPhone                                       0
# zztkv1gkse iPhone                                  519724
# zzu3u71odh Mac Desktop                             427371
# zzu6ezwap2 -unknown-                               594505
#            Android Phone                                0
# zzunwylrfv Mac Desktop                            1106898
#            iPad Tablet                            1329997
#            iPhone                                 4804972
# zzuy4rvdki iPad Tablet                             124742
# zzv6z6rjr9 Linux Desktop                          1565492
# zzv8sgicbk Mac Desktop                             463085
# zzvatt4dio Mac Desktop                           11666086
# zzvg4emw5w Mac Desktop                            3065929
# zzvr84im58 -unknown-                                  183
#            iPhone                                   75887
# zzw7kydxfa Mac Desktop                               1031
# zzx06inhbv iPhone                                       0
# zzx0hfd74v Android Phone                           211506
# zzx5wp3lqu Windows Desktop                         433105
#            iPhone                                   82632
# zzxox7jnrx Windows Desktop                         639436
# zzy7t0y9cm Windows Desktop                          73771
# zzysuoqg6x Windows Desktop                           1731
# zzywmcn0jv Windows Desktop                        2149949
# zzzlylp57e Windows Desktop                         430959
#
# [178236 rows x 1 columns]

# %%
SECS_ELAPS_feature = session_devices.groupby('user_id').sum()

# %%
SECS_ELAPS_feature
# Out:
#             secs_elapsed
# user_id
# 00023iyk9l        867896
# 0010k6l0om        586543
# 001wyh0pz8        282965
# 0028jgx1x1        297010
# 002qnbzfs5       6487080
# 0031awlkjq         39574
# 0035hobuyj       5724670
# 00378ocvlh       1827164
# 00389675gq       2605711
# 003iamz20l       1590236
# 0048rkdgb1        329852
# 0057snrdpu       1323458
# 005jc3nbmb       2793945
# 005v5uf4dh        177779
# 0063bawn05       2978016
# 006ml14zc1        204263
# 006mls2sjw       2424268
# 006t3vhawl        815416
# 006z8b0uws        324222
# 0075z9e9xv       3586976
# 007gj7kqdk        370406
# 009a40t3dk       2079299
# 00a8dbifj8        496196
# 00allnceb8             0
# 00an0o6c07        462755
# 00b9hfwaak        889009
# 00bn6hu437        913400
# 00bowi9sn3         75568
# 00bqkh0g5i           874
# 00bxmflswn       3406670
# ...                  ...
# zzq90ckj2z        599743
# zzqb2sn066        580836
# zzr1rkdsh9       2237808
# zzrnx9rqi5       1164639
# zzsoxtv8zb       5403320
# zzsslqqkee        390512
# zzsszlux3t           976
# zzswqjsqy4       1498805
# zzt5gpsyqa       1233287
# zzt8w28nl5       2094949
# zztaeo9wd5        670646
# zztkv1gkse        519724
# zzu3u71odh        427371
# zzu6ezwap2        594505
# zzunwylrfv       7241867
# zzuy4rvdki        124742
# zzv6z6rjr9       1565492
# zzv8sgicbk        463085
# zzvatt4dio      11666086
# zzvg4emw5w       3065929
# zzvr84im58         76070
# zzw7kydxfa          1031
# zzx06inhbv             0
# zzx0hfd74v        211506
# zzx5wp3lqu        515737
# zzxox7jnrx        639436
# zzy7t0y9cm         73771
# zzysuoqg6x          1731
# zzywmcn0jv       2149949
# zzzlylp57e        430959
#
# [135483 rows x 1 columns]

# %%
## Let's create a "Primary Device Feature"

# %%
A = session_devices.groupby(['user_id','device_type']).sum()
A
# Out:
#                                              secs_elapsed
# user_id    device_type
# 00023iyk9l Mac Desktop                             295642
#            iPhone                                  572254
# 0010k6l0om Mac Desktop                             586543
# 001wyh0pz8 Android App Unknown Phone/Tablet        282965
# 0028jgx1x1 -unknown-                               297010
#            Android Phone                                0
# 002qnbzfs5 -unknown-                               203511
#            iPhone                                 6283569
# 0031awlkjq iPhone                                   39574
# 0035hobuyj Mac Desktop                            5724670
# 00378ocvlh Mac Desktop                            1827164
# 00389675gq Android Phone                           236259
#            Windows Desktop                        2369452
# 003iamz20l iPad Tablet                            1590236
# 0048rkdgb1 iPhone                                  329852
# 0057snrdpu Android Phone                             4268
#            iPhone                                 1319190
# 005jc3nbmb Windows Desktop                         994093
#            iPhone                                 1799852
# 005v5uf4dh iPhone                                  177779
# 0063bawn05 Mac Desktop                            2978016
# 006ml14zc1 Mac Desktop                             204263
# 006mls2sjw Mac Desktop                            2424268
# 006t3vhawl iPad Tablet                             815416
# 006z8b0uws Android Phone                           234868
#            Mac Desktop                              89354
# 0075z9e9xv Mac Desktop                            3501123
#            Windows Desktop                          85853
# 007gj7kqdk Windows Desktop                         370406
# 009a40t3dk -unknown-                                53709
# ...                                                   ...
# zzt5gpsyqa Mac Desktop                             878825
#            iPhone                                  354462
# zzt8w28nl5 Mac Desktop                            1083981
#            Windows Desktop                        1010968
# zztaeo9wd5 -unknown-                               670646
#            iPhone                                       0
# zztkv1gkse iPhone                                  519724
# zzu3u71odh Mac Desktop                             427371
# zzu6ezwap2 -unknown-                               594505
#            Android Phone                                0
# zzunwylrfv Mac Desktop                            1106898
#            iPad Tablet                            1329997
#            iPhone                                 4804972
# zzuy4rvdki iPad Tablet                             124742
# zzv6z6rjr9 Linux Desktop                          1565492
# zzv8sgicbk Mac Desktop                             463085
# zzvatt4dio Mac Desktop                           11666086
# zzvg4emw5w Mac Desktop                            3065929
# zzvr84im58 -unknown-                                  183
#            iPhone                                   75887
# zzw7kydxfa Mac Desktop                               1031
# zzx06inhbv iPhone                                       0
# zzx0hfd74v Android Phone                           211506
# zzx5wp3lqu Windows Desktop                         433105
#            iPhone                                   82632
# zzxox7jnrx Windows Desktop                         639436
# zzy7t0y9cm Windows Desktop                          73771
# zzysuoqg6x Windows Desktop                           1731
# zzywmcn0jv Windows Desktop                        2149949
# zzzlylp57e Windows Desktop                         430959
#
# [178236 rows x 1 columns]

# %%
A.head(20).unstack()
# Out:
#             secs_elapsed                                                 \
# device_type    -unknown- Android App Unknown Phone/Tablet Android Phone
# user_id
# 00023iyk9l           NaN                              NaN           NaN
# 0010k6l0om           NaN                              NaN           NaN
# 001wyh0pz8           NaN                           282965           NaN
# 0028jgx1x1        297010                              NaN             0
# 002qnbzfs5        203511                              NaN           NaN
# 0031awlkjq           NaN                              NaN           NaN
# 0035hobuyj           NaN                              NaN           NaN
# 00378ocvlh           NaN                              NaN           NaN
# 00389675gq           NaN                              NaN        236259
# 003iamz20l           NaN                              NaN           NaN
# 0048rkdgb1           NaN                              NaN           NaN
# 0057snrdpu           NaN                              NaN          4268
# 005jc3nbmb           NaN                              NaN           NaN
# 005v5uf4dh           NaN                              NaN           NaN
#
#
# device_type Mac Desktop Windows Desktop iPad Tablet   iPhone
# user_id
# 00023iyk9l       295642             NaN         NaN   572254
# 0010k6l0om       586543             NaN         NaN      NaN
# 001wyh0pz8          NaN             NaN         NaN      NaN
# 0028jgx1x1          NaN             NaN         NaN      NaN
# 002qnbzfs5          NaN             NaN         NaN  6283569
# 0031awlkjq          NaN             NaN         NaN    39574
# 0035hobuyj      5724670             NaN         NaN      NaN
# 00378ocvlh      1827164             NaN         NaN      NaN
# 00389675gq          NaN         2369452         NaN      NaN
# 003iamz20l          NaN             NaN     1590236      NaN
# 0048rkdgb1          NaN             NaN         NaN   329852
# 0057snrdpu          NaN             NaN         NaN  1319190
# 005jc3nbmb          NaN          994093         NaN  1799852
# 005v5uf4dh          NaN             NaN         NaN   177779

# %%
# Imports

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# c:\Anaconda3\lib\site-packages\matplotlib\__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
print(len(session_grouped))
print(len(X))
print(len(Y))
print(len(X)+len(Y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d995903c0fb6> in <module>()
# ----> 1 print(len(session_grouped))
#       2 print(len(X))
#       3 print(len(Y))
#       4 print(len(X)+len(Y))
#
# NameError: name 'session_grouped' is not defined

# %%
# get airbnb & test csv files as a DataFrame
train_users  = pd.read_csv('../input/train_users_2.csv')
session_df = pd.read_csv('../input/sessions.csv')
test_users    = pd.read_csv('../input/test_users.csv')

# %%
all_users = pd.concat([train_users,test_users],axis=0,ignore_index=True)

# %%
i = 0

# %%
all_users.shape
# Out:
# (275547, 16)

# %%
session_df['secs_elapsed'].fillna(0,inplace=True) # Most missing times are for create, authenticate, and index actions.

# %%
session_grouped = session_df.groupby('user_id').agg({'action': 'count',
                                                    'device_type':'first',
                                                    'secs_elapsed':sum})

# %%
session_df.head(2)
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
#
#        device_type  secs_elapsed  minutes_elapsed  hours_elapsed  days_elapsed
# 0  Windows Desktop           319                5            0.1           0.0
# 1  Windows Desktop         67753             1129           18.8           0.8

# %%
session_action_large = session_df[session_df['secs_elapsed']>3*3600].groupby('user_id')

# %%
num_devices = session_df.groupby('user_id')['device_type'].agg(lambda x: len(np.unique(x.values)))
num_devices
# Out:
# user_id
# 00023iyk9l    2
# 0010k6l0om    1
# 001wyh0pz8    1
# 0028jgx1x1    2
# 002qnbzfs5    2
# 0031awlkjq    1
# 0035hobuyj    1
# 00378ocvlh    1
# 00389675gq    2
# 003iamz20l    1
# 0048rkdgb1    1
# 0057snrdpu    2
# 005jc3nbmb    2
# 005v5uf4dh    1
# 0063bawn05    1
# 006ml14zc1    1
# 006mls2sjw    1
# 006t3vhawl    1
# 006z8b0uws    2
# 0075z9e9xv    2
# 007gj7kqdk    1
# 009a40t3dk    3
# 00a8dbifj8    1
# 00allnceb8    1
# 00an0o6c07    2
# 00b9hfwaak    1
# 00bn6hu437    1
# 00bowi9sn3    1
# 00bqkh0g5i    1
# 00bxmflswn    2
#              ..
# zzq90ckj2z    1
# zzqb2sn066    2
# zzr1rkdsh9    1
# zzrnx9rqi5    1
# zzsoxtv8zb    2
# zzsslqqkee    1
# zzsszlux3t    1
# zzswqjsqy4    1
# zzt5gpsyqa    2
# zzt8w28nl5    2
# zztaeo9wd5    2
# zztkv1gkse    1
# zzu3u71odh    1
# zzu6ezwap2    2
# zzunwylrfv    3
# zzuy4rvdki    1
# zzv6z6rjr9    1
# zzv8sgicbk    1
# zzvatt4dio    1
# zzvg4emw5w    1
# zzvr84im58    2
# zzw7kydxfa    1
# zzx06inhbv    1
# zzx0hfd74v    1
# zzx5wp3lqu    2
# zzxox7jnrx    1
# zzy7t0y9cm    1
# zzysuoqg6x    1
# zzywmcn0jv    1
# zzzlylp57e    1
# Name: device_type, dtype: int64

# %%
user_af1
# Out:
#             num_device_types  num_sessions  num_days_active  \
# 00023iyk9l                 2             4                3
# 0010k6l0om                 1             6                3
# 001wyh0pz8                 1             2                1
# 0028jgx1x1                 2             3                2
# 002qnbzfs5                 2            24               15
# 0031awlkjq                 1             1                1
# 0035hobuyj                 1            27               15
# 00378ocvlh                 1             8                5
# 00389675gq                 2            21               10
# 003iamz20l                 1            15                3
# 0048rkdgb1                 1             3                2
# 0057snrdpu                 2             5                2
# 005jc3nbmb                 2             6                4
# 005v5uf4dh                 1             2                1
# 0063bawn05                 1             8                6
# 006ml14zc1                 1             3                1
# 006mls2sjw                 1            15                5
# 006t3vhawl                 1             9                6
# 006z8b0uws                 2             3                2
# 0075z9e9xv                 2            15                6
# 007gj7kqdk                 1             2                2
# 009a40t3dk                 3             7                4
# 00a8dbifj8                 1             4                2
# 00allnceb8                 1             1                1
# 00an0o6c07                 2             4                3
# 00b9hfwaak                 1             7                5
# 00bn6hu437                 1             7                4
# 00bowi9sn3                 1             2                1
# 00bqkh0g5i                 1             1                1
# 00bxmflswn                 2            16                7
# ...                      ...           ...              ...
# zzq90ckj2z               NaN           NaN              NaN
# zzqb2sn066               NaN           NaN              NaN
# zzr1rkdsh9               NaN           NaN              NaN
# zzrnx9rqi5               NaN           NaN              NaN
# zzsoxtv8zb               NaN           NaN              NaN
# zzsslqqkee               NaN           NaN              NaN
# zzsszlux3t               NaN           NaN              NaN
# zzswqjsqy4               NaN           NaN              NaN
# zzt5gpsyqa               NaN           NaN              NaN
# zzt8w28nl5               NaN           NaN              NaN
# zztaeo9wd5               NaN           NaN              NaN
# zztkv1gkse               NaN           NaN              NaN
# zzu3u71odh               NaN           NaN              NaN
# zzu6ezwap2               NaN           NaN              NaN
# zzunwylrfv               NaN           NaN              NaN
# zzuy4rvdki               NaN           NaN              NaN
# zzv6z6rjr9               NaN           NaN              NaN
# zzv8sgicbk               NaN           NaN              NaN
# zzvatt4dio               NaN           NaN              NaN
# zzvg4emw5w               NaN           NaN              NaN
# zzvr84im58               NaN           NaN              NaN
# zzw7kydxfa               NaN           NaN              NaN
# zzx06inhbv               NaN           NaN              NaN
# zzx0hfd74v               NaN           NaN              NaN
# zzx5wp3lqu               NaN           NaN              NaN
# zzxox7jnrx               NaN           NaN              NaN
# zzy7t0y9cm               NaN           NaN              NaN
# zzysuoqg6x               NaN           NaN              NaN
# zzywmcn0jv               NaN           NaN              NaN
# zzzlylp57e               NaN           NaN              NaN
#
#             total_session_time   avg_session_time  max_session_time  \
# 00023iyk9l               127804       3258.666667       4713.111111
# 0010k6l0om               210700       2816.267983       5707.291667
# 001wyh0pz8               232417       2825.486307       3184.944444
# 0028jgx1x1               165126       5880.275000       6825.200000
# 002qnbzfs5              2128886               NaN               NaN
# 0031awlkjq                39574       4946.750000       4946.750000
# 0035hobuyj              1820755               NaN               NaN
# 00378ocvlh               344277               NaN               NaN
# 00389675gq               588327               NaN               NaN
# 003iamz20l               535816               NaN               NaN
# 0048rkdgb1               198596       3424.794118       6895.882353
# 0057snrdpu               154545               NaN               NaN
# 005jc3nbmb               112563               NaN               NaN
# 007gj7kqdk               298145         298145.000000
# 009a40t3dk              1028988         330245.333333
# 00a8dbifj8               109687          75779.666667
# 00allnceb8                  NaN                   NaN
# 00an0o6c07               133824          88179.666667
# 00b9hfwaak               219395         108248.500000
# 00bn6hu437               253312         132755.500000
# 00bowi9sn3                52923          52923.000000
# 00bqkh0g5i                  NaN                   NaN
# 00bxmflswn              1307338         207034.800000
# ...                         ...                   ...
# zzq90ckj2z                  NaN                   NaN
# zzqb2sn066                  NaN                   NaN
# zzr1rkdsh9                  NaN                   NaN
# zzrnx9rqi5                  NaN                   NaN
# zzsoxtv8zb                  NaN                   NaN
# zzsslqqkee                  NaN                   NaN
# zzsszlux3t                  NaN                   NaN
# zzswqjsqy4                  NaN                   NaN
# zzt5gpsyqa                  NaN                   NaN
# zzt8w28nl5                  NaN                   NaN
# zztaeo9wd5                  NaN                   NaN
# zztkv1gkse                  NaN                   NaN
# zzu3u71odh                  NaN                   NaN
# zzu6ezwap2                  NaN                   NaN
# zzunwylrfv                  NaN                   NaN
# zzuy4rvdki                  NaN                   NaN
# zzv6z6rjr9                  NaN                   NaN
# zzv8sgicbk                  NaN                   NaN
# zzvatt4dio                  NaN                   NaN
# zzvg4emw5w                  NaN                   NaN
# zzvr84im58                  NaN                   NaN
# zzw7kydxfa                  NaN                   NaN
# zzx06inhbv                  NaN                   NaN
# zzx0hfd74v                  NaN                   NaN
# zzx5wp3lqu                  NaN                   NaN
# zzxox7jnrx                  NaN                   NaN
# zzy7t0y9cm                  NaN                   NaN
# zzysuoqg6x                  NaN                   NaN
# zzywmcn0jv                  NaN                   NaN
# zzzlylp57e                  NaN                   NaN
#
# [135483 rows x 11 columns]

# %%
num_devices.shape
# Out:
# (135483,)

# %%
in_session_actions = session_df[session_df['secs_elapsed']<3600].groupby('user_id')
AA = in_session_actions['secs_elapsed'].agg({'total_session_times': np.sum,
                                        'mean_secs_per_action' : np.mean,
                                            'num_actions_insession' : np.size})

between_session_actions = session_df[session_df['secs_elapsed']>12*3600].groupby('user_id')
BB = between_session_actions['secs_elapsed'].agg({'num_sessions': np.size,
                                            'mean_between_sessions' : np.mean,
                                            'max_between_sessions': np.max
                                            })

SessionFeatures2 = pd.merge(AA,BB,how='outer',left_index=True,right_index=True)
#SessionFeatures2.merge(num_devices,how='outer',left_index=True,right_index=True)

SessionFeatures2['num_devices'] = session_df.groupby('user_id')['device_type'].agg(lambda x: len(np.unique(x.values)))
SessionFeatures2.fillna(0,inplace=True)
SessionFeatures2['num_sessions'] += 1 

SessionFeatures2.sort_values(by='num_sessions').head(10)
# Out:
#             total_session_times  mean_secs_per_action  num_actions_insession  \
# user_id
# 5d1bf2j5yh                 2959            493.166667                      6
# 606nqrstwm                 1119            559.500000                      2
# bovt8ejztj                  431            215.500000                      2
# 605yfalaw1                 2557            511.400000                      5
# p7eec9iand                  664            332.000000                      2
# p7hebvt61f                21919            534.609756                     41
# p7leqgdfys                10337            397.576923                     26
# 601r7d6r2a                45749           1063.930233                     43
# p7qej1ks0e                    0              0.000000                      1
# p7r2k0x75f                 3612           1204.000000                      3
#
#             mean_between_sessions  max_between_sessions  num_sessions  \
# user_id
# 5d1bf2j5yh                      0                     0             1
# 606nqrstwm                      0                     0             1
# bovt8ejztj                      0                     0             1
# 605yfalaw1                      0                     0             1
# p7eec9iand                      0                     0             1
# p7hebvt61f                      0                     0             1
# p7leqgdfys                      0                     0             1
# 601r7d6r2a                      0                     0             1
# p7qej1ks0e                      0                     0             1
# p7r2k0x75f                      0                     0             1
#
#             num_devices
# user_id
# 5d1bf2j5yh            1
# 606nqrstwm            1
# bovt8ejztj            1
# 605yfalaw1            1
# p7eec9iand            1
# p7hebvt61f            1
# p7leqgdfys            1
# 601r7d6r2a            1
# p7qej1ks0e            1
# p7r2k0x75f            1

# %%
SessionFeatures2
# Out:
#             total_session_times  mean_secs_per_action  num_actions_insession  \
# user_id
# 00023iyk9l                22901            763.366667                     30
# 0010k6l0om                32545            692.446809                     47
# 001wyh0pz8                71529            993.458333                     72
# 0028jgx1x1                 7516            417.555556                     18
# 002qnbzfs5               369804            613.273632                    603
# 0031awlkjq                 6219           1036.500000                      6
# 0035hobuyj               292291            811.919444                    360
# 00378ocvlh                39055            887.613636                     44
# 00389675gq                73275            642.763158                    114
# 003iamz20l                69249            581.924370                    119
# 0048rkdgb1                 9408            285.090909                     33
# 0057snrdpu                 9994            624.625000                     16
# 005jc3nbmb                17555           1350.384615                     13
# 005v5uf4dh                10583            364.931034                     29
# 0063bawn05                15271           1090.785714                     14
# 006ml14zc1                16748            837.400000                     20
# 006mls2sjw               101411            724.364286                    140
# 006t3vhawl                13896            992.571429                     14
# 006z8b0uws                 6515            814.375000                      8
# 0075z9e9xv               160524            408.458015                    393
# 007gj7kqdk                 4956           1239.000000                      4
# 009a40t3dk                13573           1131.083333                     12
# 00a8dbifj8                49292            880.214286                     56
# 00allnceb8                    0              0.000000                      1
# 00an0o6c07                52080            930.000000                     56
# 00b9hfwaak                24678            474.576923                     52
# 00bn6hu437                22228            966.434783                     23
# 00bowi9sn3                 8921           1115.125000                      8
# 00bqkh0g5i                  874            437.000000                      2
# 00bxmflswn                75707           1113.338235                     68
# ...                         ...                   ...                    ...
# zzq90ckj2z                17093           1139.533333                     15
# zzqb2sn066                 4328            541.000000                      8
# zzr1rkdsh9                47630            690.289855                     69
# zzrnx9rqi5                12795            752.647059                     17
# zzsoxtv8zb                30445            951.406250                     32
# zzsslqqkee                 7134            713.400000                     10
# zzsszlux3t                  976            244.000000                      4
# zzswqjsqy4                23294            541.720930                     43
# zzt5gpsyqa                23518            635.621622                     37
# zzt8w28nl5                70748            508.978417                    139
# zztaeo9wd5                26156            653.900000                     40
# zztkv1gkse                15919            324.877551                     49
# zzu3u71odh                46004            697.030303                     66
# zzu6ezwap2                10451           1045.100000                     10
# zzunwylrfv               129818            422.859935                    307
# zzuy4rvdki                 6148            768.500000                      8
# zzv6z6rjr9                53476           1304.292683                     41
# zzv8sgicbk                13906           1069.692308                     13
# zzvatt4dio               230731            787.477816                    293
# zzvg4emw5w                62032            473.526718                    131
# zzywmcn0jv          285974.000000                525635             8
# zzzlylp57e           53425.000000                 61988             3
#
#             num_devices
# user_id
# 00023iyk9l            2
# 0010k6l0om            1
# 001wyh0pz8            1
# 0028jgx1x1            2
# 002qnbzfs5            2
# 0031awlkjq            1
# 0035hobuyj            1
# 00378ocvlh            1
# 00389675gq            2
# 003iamz20l            1
# 0048rkdgb1            1
# 0057snrdpu            2
# 005jc3nbmb            2
# 005v5uf4dh            1
# 0063bawn05            1
# 006ml14zc1            1
# 006mls2sjw            1
# 006t3vhawl            1
# 006z8b0uws            2
# 0075z9e9xv            2
# 007gj7kqdk            1
# 009a40t3dk            3
# 00a8dbifj8            1
# 00allnceb8            1
# 00an0o6c07            2
# 00b9hfwaak            1
# 00bn6hu437            1
# 00bowi9sn3            1
# 00bqkh0g5i            1
# 00bxmflswn            2
# ...                 ...
# zzq90ckj2z            1
# zzqb2sn066            2
# zzr1rkdsh9            1
# zzrnx9rqi5            1
# zzsoxtv8zb            2
# zzsslqqkee            1
# zzsszlux3t            1
# zzswqjsqy4            1
# zzt5gpsyqa            2
# zzt8w28nl5            2
# zztaeo9wd5            2
# zztkv1gkse            1
# zzu3u71odh            1
# zzu6ezwap2            2
# zzunwylrfv            3
# zzuy4rvdki            1
# zzv6z6rjr9            1
# zzv8sgicbk            1
# zzvatt4dio            1
# zzvg4emw5w            1
# zzvr84im58            2
# zzw7kydxfa            1
# zzx06inhbv            1
# zzx0hfd74v            1
# zzx5wp3lqu            2
# zzxox7jnrx            1
# zzy7t0y9cm            1
# zzysuoqg6x            1
# zzywmcn0jv            1
# zzzlylp57e            1
#
# [135483 rows x 7 columns]

# %%
X = pd.merge(SessionFeatures2,train_users[['id','country_destination']],how='inner',left_index=True,right_on='id').drop('id',axis=1)
y = X['country_destination']!='NDF'
X.drop('country_destination',axis=1,inplace=True)

# %%
X.head(3)
# Out:
#         total_session_times  mean_secs_per_action  num_actions_insession  \
# 189274                22901            763.366667                     30
# 179944                71529            993.458333                     72
# 208158                 7516            417.555556                     18
#
#         mean_between_sessions  max_between_sessions  num_sessions  num_devices
# 189274                 348491                567165             3            2
# 179944                  50548                 50548             2            1
# 208158                  65942                 84636             3            2

# %%
y.head(3)
# Out:
# 189274     True
# 179944    False
# 208158    False
# Name: country_destination, dtype: bool

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score


RF = RandomForestClassifier(oob_score=True,n_estimators=200,class_weight='balanced')
CV_score = cross_val_score(RF,X,y,scoring='accuracy', cv=5, verbose=1)
print('CV scores = ',CV_score)
print('Mean CV score = ', np.mean(CV_score))
# Out:
# CV scores =  [ 0.59990517  0.60692271  0.6028585   0.59310438  0.60791221]
# Mean CV score =  0.602140594825
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.2min finished

# %%
pd.merge(AA,BB,how='outer',left_index=True,right_index=True).sort_values(by='total_session_times').shape
# Out:
# (135483, 6)

# %%
num_sessions = session_action_large['secs_elapsed'].count()

# %%
unique_ids = session_grouped.index.values
user_af = pd.DataFrame(index=unique_ids) ## Create collected dataframe for new features

# %%
user = session_df[session_df['user_id']==unique_ids[0]]

user['minutes_elapsed']=np.round(user['secs_elapsed']/60)
user['hours_elapsed']= np.round(user['secs_elapsed']/3600,1)
user['days_elapsed']= np.round(user['secs_elapsed']/(3600*24),1)

user.head(3)
# Out:
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             user_id          action action_type        action_detail  \
# 3573923  00023iyk9l           index        view  view_search_results
# 3573924  00023iyk9l       dashboard        view            dashboard
# 3573925  00023iyk9l  header_userpic        data       header_userpic
#
#          device_type  secs_elapsed  minutes_elapsed  hours_elapsed  \
# 3573923  Mac Desktop         20438              341            5.7
# 3573924  Mac Desktop           787               13            0.2
# 3573925  Mac Desktop           850               14            0.2
#
#          days_elapsed
# 3573923           0.2
# 3573924           0.0
# 3573925           0.0

# %%
user_af.loc[unique_ids[i]]
# Out:
# num_device_types             2.000000
# num_sessions                 4.000000
# num_days_active              3.000000
# total_session_time      127804.000000
# avg_session_time          3258.666667
# max_session_time          4713.111111
# max_session_action          18.000000
# mean_session_action          9.250000
# mean_secs_per_action       763.366667
# max_between_session     567165.000000
# mean_between_session    246697.333333
# Name: 00023iyk9l, dtype: float64

# %%
session_df['minutes_elapsed']=np.round(session_df['secs_elapsed']/60)
session_df['hours_elapsed']= np.round(session_df['secs_elapsed']/3600,1)
session_df['days_elapsed']= np.round(session_df['secs_elapsed']/(3600*24),1)

# %%
unique_ids = session_grouped.index.values
user_af = pd.DataFrame(index=unique_ids) ## Create collected dataframe for new features

# %%
for i in unique_ids:
    user = session_df[session_df['user_id']==unique_ids[i]]

# %%
75000*.5/(3600)
# Out:
# 10.416666666666666

# %%
sessions
# Out:
#              user_id                 action       action_type  \
# 0         d1mm9tcy42                 lookup               NaN
# 1         d1mm9tcy42         search_results             click
# 2         d1mm9tcy42                 lookup               NaN
# 3         d1mm9tcy42         search_results             click
# 4         d1mm9tcy42                 lookup               NaN
# 5         d1mm9tcy42         search_results             click
# 6         d1mm9tcy42                 lookup               NaN
# 7         d1mm9tcy42            personalize              data
# 8         d1mm9tcy42                  index              view
# 9         d1mm9tcy42                 lookup               NaN
# 10        d1mm9tcy42         search_results             click
# 11        d1mm9tcy42                 lookup               NaN
# 12        d1mm9tcy42            personalize              data
# 13        d1mm9tcy42                  index              view
# 14        d1mm9tcy42       similar_listings              data
# 15        d1mm9tcy42  ajax_refresh_subtotal             click
# 16        d1mm9tcy42       similar_listings              data
# 17        d1mm9tcy42  ajax_refresh_subtotal             click
# 18        d1mm9tcy42                   show               NaN
# 19        d1mm9tcy42            personalize              data
# 20        d1mm9tcy42                   show              view
# 21        d1mm9tcy42                 lookup               NaN
# 22        d1mm9tcy42         search_results             click
# 23        d1mm9tcy42                 lookup               NaN
# 24        d1mm9tcy42         search_results             click
# 25        d1mm9tcy42            personalize              data
# 26        d1mm9tcy42                 lookup               NaN
# 27        d1mm9tcy42                  index              view
# 28        d1mm9tcy42                   show               NaN
# 29        d1mm9tcy42            personalize              data
# ...              ...                    ...               ...
# 10567707  87k0fy4ugm                 update            submit
# 10567708  87k0fy4ugm                 create         -unknown-
# 10567709  87k0fy4ugm            personalize              data
# 10567710  87k0fy4ugm         header_userpic              data
# 10567711  87k0fy4ugm                 create            submit
# 10567712  87k0fy4ugm                   show              view
# 10567713  87k0fy4ugm         header_userpic              data
# 10567714  87k0fy4ugm            personalize              data
# 10567715  87k0fy4ugm  ajax_refresh_subtotal             click
# 10567716  87k0fy4ugm       similar_listings              data
# 10567717  87k0fy4ugm                  index              view
# 10567718  87k0fy4ugm          confirm_email             click
# 10567719  87k0fy4ugm           authenticate            submit
# 10567720  87k0fy4ugm              dashboard              view
# 10567721  9uqfg8txu3                   show              view
# 10567722  9uqfg8txu3                 update            submit
# 10567723  9uqfg8txu3                   edit              view
# 10567724  9uqfg8txu3  languages_multiselect         -unknown-
# 10567725  9uqfg8txu3                 create            submit
# 10567726  9uqfg8txu3               callback  partner_callback
# 10567727  9uqfg8txu3                 active         -unknown-
# 10567728  9uqfg8txu3                 create            submit
# 10567729  9uqfg8txu3         header_userpic              data
# 10567730  9uqfg8txu3                   edit              view
# 10567731  9uqfg8txu3                   edit              view
# 10567732  9uqfg8txu3              dashboard              view
# 10567733  9uqfg8txu3                   edit              view
# 10567734  9uqfg8txu3          webcam_upload         -unknown-
# 10567735  9uqfg8txu3                 active         -unknown-
# 10567736  9uqfg8txu3       show_personalize              data
#
#                         action_detail      device_type  secs_elapsed  \
# 0                                 NaN  Windows Desktop           319
# 1                 view_search_results  Windows Desktop         67753
# 2                                 NaN  Windows Desktop           301
# 3                 view_search_results  Windows Desktop         22141
# 4                                 NaN  Windows Desktop           435
# 5                 view_search_results  Windows Desktop          7703
# 6                                 NaN  Windows Desktop           115
# 7             wishlist_content_update  Windows Desktop           831
# 8                 view_search_results  Windows Desktop         20842
# 9                                 NaN  Windows Desktop           683
# 10                view_search_results  Windows Desktop         59274
# 11                                NaN  Windows Desktop            95
# 12            wishlist_content_update  Windows Desktop          1399
# 13                view_search_results  Windows Desktop         74886
# 14                   similar_listings  Windows Desktop           255
# 15        change_trip_characteristics  Windows Desktop          8134
# 16                   similar_listings  Windows Desktop           183
# 17        change_trip_characteristics  Windows Desktop        175570
# 18                                NaN  Windows Desktop            86
# 19            wishlist_content_update  Windows Desktop          1535
# 20                                 p3  Windows Desktop         83251
# 21                                NaN  Windows Desktop           360
# 22                view_search_results  Windows Desktop          2488
# 23                                NaN  Windows Desktop           456
# 24                view_search_results  Windows Desktop         10053
# 25            wishlist_content_update  Windows Desktop            50
# 26                                NaN  Windows Desktop          1996
# 27                view_search_results  Windows Desktop         82263
# 28                                NaN  Windows Desktop           102
# 29            wishlist_content_update  Windows Desktop           673
# ...                               ...              ...           ...
# 10567707               update_listing      Mac Desktop          3490
# 10567708                    -unknown-      Mac Desktop         26491
# 10567709      wishlist_content_update      Mac Desktop           189
# 10567710               header_userpic      Mac Desktop           698
# 10567711                  create_user      Mac Desktop             0
# 10567712                           p3      Mac Desktop         21062
# 10567713               header_userpic           iPhone           897
# 10567714      wishlist_content_update      Mac Desktop            17
# 10567715  change_trip_characteristics      Mac Desktop           602
# 10567716             similar_listings      Mac Desktop           257
# 10567717          view_search_results      Mac Desktop         14711
# 10567718           confirm_email_link           iPhone        253296
# 10567719                        login           iPhone         26581
# 10567720                    dashboard           iPhone          2694
# 10567721                 user_profile  Windows Desktop           447
# 10567722          update_user_profile  Windows Desktop        124020
# 10567723                 edit_profile  Windows Desktop         22920
# 10567724                    -unknown-  Windows Desktop        575816
# 10567725         create_phone_numbers  Windows Desktop         57382
# 10567726               oauth_response  Windows Desktop             0
# 10567727                    -unknown-        -unknown-           353
# 10567728         create_phone_numbers  Windows Desktop         27206
# 10567729               header_userpic  Windows Desktop          1939
# 10567730                 edit_profile  Windows Desktop       1752436
# 10567731                 edit_profile  Windows Desktop         15875
# 10567732                    dashboard  Windows Desktop           556
# 10567733                 edit_profile  Windows Desktop          6624
# 10567734                    -unknown-  Windows Desktop        200125
# 10567735                    -unknown-        -unknown-         17624
# 10567736  user_profile_content_update  Windows Desktop          1221
#
#           minutes_elapsed  hours_elapsed  days_elapsed
# 0                       5            0.1           0.0
# 1                    1129           18.8           0.8
# 2                       5            0.1           0.0
# 3                     369            6.2           0.3
# 4                       7            0.1           0.0
# 5                     128            2.1           0.1
# 6                       2            0.0           0.0
# 7                      14            0.2           0.0
# 8                     347            5.8           0.2
# 9                      11            0.2           0.0
# 10                    988           16.5           0.7
# 11                      2            0.0           0.0
# 12                     23            0.4           0.0
# 13                   1248           20.8           0.9
# 14                      4            0.1           0.0
# 15                    136            2.3           0.1
# 16                      3            0.1           0.0
# 17                   2926           48.8           2.0
# 18                      1            0.0           0.0
# 19                     26            0.4           0.0
# 20                   1388           23.1           1.0
# 21                      6            0.1           0.0
# 22                     41            0.7           0.0
# 23                      8            0.1           0.0
# 24                    168            2.8           0.1
# 25                      1            0.0           0.0
# 26                     33            0.6           0.0
# 27                   1371           22.9           1.0
# 28                      2            0.0           0.0
# 29                     11            0.2           0.0
# ...                   ...            ...           ...
# 10567707               58            1.0           0.0
# 10567708              442            7.4           0.3
# 10567709                3            0.1           0.0
# 10567710               12            0.2           0.0
# 10567711                0            0.0           0.0
# 10567712              351            5.9           0.2
# 10567713               15            0.2           0.0
# 10567714                0            0.0           0.0
# 10567715               10            0.2           0.0
# 10567716                4            0.1           0.0
# 10567717              245            4.1           0.2
# 10567718             4222           70.4           2.9
# 10567719              443            7.4           0.3
# 10567720               45            0.7           0.0
# 10567721                7            0.1           0.0
# 10567722             2067           34.4           1.4
# 10567723              382            6.4           0.3
# 10567724             9597          159.9           6.7
# 10567725              956           15.9           0.7
# 10567726                0            0.0           0.0
# 10567727                6            0.1           0.0
# 10567728              453            7.6           0.3
# 10567729               32            0.5           0.0
# 10567730            29207          486.8          20.3
# 10567731              265            4.4           0.2
# 10567732                9            0.2           0.0
# 10567733              110            1.8           0.1
# 10567734             3335           55.6           2.3
# 10567735              294            4.9           0.2
# 10567736               20            0.3           0.0
#
# [10567737 rows x 9 columns]

# %%
unique_ids = session_grouped.index.values
user_af = pd.DataFrame(index=unique_ids) ## Create collected dataframe for new features

for i in range(20):
    user = session_df[session_df['user_id']==unique_ids[i]]

    ## Number of different devices used
    user_af.loc[unique_ids[i],'num_device_types'] = len(np.unique(user['device_type'].values))


    ## Number of sessions
    tbs = 10 # elapsed time defining new session
    user_af.loc[unique_ids[i],'num_sessions'] = sum(user['hours_elapsed']>10)+1


    ## Number of different days
    user_af.loc[unique_ids[i],'num_days_active'] = sum(user['days_elapsed']>=1)+1


    ### Time during sessions
    tbs = 10
    split_indices = user['hours_elapsed']>tbs
    time_in_sessions = user[user['hours_elapsed']<=tbs]['secs_elapsed']

    user_af.loc[unique_ids[i],'total_session_time '] = time_in_sessions.sum()

    #Average and Max Session Times
    B = np.split(time_in_sessions,np.where(split_indices)[0]) # Split all sessions into groups
    session_times = [b.sum() for b in B]
    #print(session_times)
    session_action_count = [len(b) for b in B]

    user_af.loc[unique_ids[i],'avg_session_time'] = np.mean(session_times)
    user_af.loc[unique_ids[i],'max_session_time'] = np.max(session_times)
    user_af.loc[unique_ids[i],'max_session_action'] = np.max(session_action_count)
    user_af.loc[unique_ids[i],'mean_session_action'] = np.mean(session_action_count)


    ## Average Time per Action, excluding large gaps
    user_af.loc[unique_ids[i],'mean_secs_per_action'] = np.mean(user[user['secs_elapsed']<=3600]['secs_elapsed'])



    ### Time between sessions
    time_between_sessions = user[user['hours_elapsed']>tbs]['secs_elapsed']

    user_af.loc[unique_ids[i],'max_between_session'] = time_between_sessions.max()
    user_af.loc[unique_ids[i],'mean_between_session'] = time_between_sessions.mean()

# %%
user_af
# Out:
#             num_device_types  num_sessions  num_days_active  \
# 00023iyk9l                 2             4                3
# 0010k6l0om                 1             6                3
# 001wyh0pz8                 1             2                1
# 0028jgx1x1                 2             3                2
# 002qnbzfs5                 2            24               15
# 0031awlkjq                 1             1                1
# 0035hobuyj                 1            27               15
# 00378ocvlh                 1             8                5
# 00389675gq                 2            21               10
# 003iamz20l                 1            15                3
# 0048rkdgb1                 1             3                2
# 0057snrdpu                 2             5                2
# 005jc3nbmb                 2             6                4
# 005v5uf4dh                 1             2                1
# 0063bawn05                 1             8                6
# 006ml14zc1                 1             3                1
# 006mls2sjw                 1            15                5
# 006t3vhawl                 1             9                6
# 006z8b0uws                 2             3                2
# 0075z9e9xv                 2            15                6
# 007gj7kqdk               NaN           NaN              NaN
# 009a40t3dk               NaN           NaN              NaN
# 00a8dbifj8               NaN           NaN              NaN
# 00allnceb8               NaN           NaN              NaN
# 00an0o6c07               NaN           NaN              NaN
# 00b9hfwaak               NaN           NaN              NaN
# 00bn6hu437               NaN           NaN              NaN
# 00bowi9sn3               NaN           NaN              NaN
# 00bqkh0g5i               NaN           NaN              NaN
# 00bxmflswn               NaN           NaN              NaN
# ...                      ...           ...              ...
# zzq90ckj2z               NaN           NaN              NaN
# zzqb2sn066               NaN           NaN              NaN
# zzr1rkdsh9               NaN           NaN              NaN
# zzrnx9rqi5               NaN           NaN              NaN
# zzsoxtv8zb               NaN           NaN              NaN
# zzsslqqkee               NaN           NaN              NaN
# zzsszlux3t               NaN           NaN              NaN
# zzswqjsqy4               NaN           NaN              NaN
# zzxox7jnrx                  NaN                   NaN
# zzy7t0y9cm                  NaN                   NaN
# zzysuoqg6x                  NaN                   NaN
# zzywmcn0jv                  NaN                   NaN
# zzzlylp57e                  NaN                   NaN
#
# [135483 rows x 11 columns]

# %%
i = 6
user = session_df[session_df['user_id']==unique_ids[i]]
user
# Out:
#           user_id                       action action_type  \
# 28395  0035hobuyj                       lookup         NaN
# 28396  0035hobuyj               search_results       click
# 28397  0035hobuyj                       lookup         NaN
# 28398  0035hobuyj               search_results       click
# 28399  0035hobuyj                       lookup         NaN
# 28400  0035hobuyj               search_results       click
# 28401  0035hobuyj                       lookup         NaN
# 28402  0035hobuyj               search_results       click
# 28403  0035hobuyj                       lookup         NaN
# 28404  0035hobuyj               search_results       click
# 28405  0035hobuyj                       lookup         NaN
# 28406  0035hobuyj               search_results       click
# 28407  0035hobuyj                       lookup         NaN
# 28408  0035hobuyj               search_results       click
# 28409  0035hobuyj                       lookup         NaN
# 28410  0035hobuyj               search_results       click
# 28411  0035hobuyj                       lookup         NaN
# 28412  0035hobuyj               search_results       click
# 28413  0035hobuyj                       lookup         NaN
# 28414  0035hobuyj                         show        view
# 28415  0035hobuyj               search_results       click
# 28416  0035hobuyj                       lookup         NaN
# 28417  0035hobuyj               search_results       click
# 28418  0035hobuyj               search_results       click
# 28419  0035hobuyj                       create      submit
# 28420  0035hobuyj               header_userpic        data
# 28421  0035hobuyj                  personalize        data
# 28422  0035hobuyj                       update   -unknown-
# 28423  0035hobuyj                        index        view
# 28424  0035hobuyj               search_results       click
# ...           ...                          ...         ...
# 28854  0035hobuyj                       lookup         NaN
# 28855  0035hobuyj               search_results       click
# 28856  0035hobuyj                       lookup         NaN
# 28857  0035hobuyj               search_results       click
# 28858  0035hobuyj                       lookup         NaN
# 28859  0035hobuyj               search_results       click
# 28860  0035hobuyj                       lookup         NaN
# 28861  0035hobuyj               search_results       click
# 28862  0035hobuyj                       lookup         NaN
# 28863  0035hobuyj               search_results       click
# 28864  0035hobuyj                       lookup         NaN
# 28865  0035hobuyj               search_results       click
# 28866  0035hobuyj                       lookup         NaN
# 28867  0035hobuyj               search_results       click
# 28868  0035hobuyj                       lookup         NaN
# 28869  0035hobuyj                         show        view
# 28870  0035hobuyj                  personalize        data
# 28871  0035hobuyj                         show         NaN
# 28872  0035hobuyj  other_hosting_reviews_first   -unknown-
# 28873  0035hobuyj        ajax_refresh_subtotal       click
# 28874  0035hobuyj             similar_listings        data
# 28875  0035hobuyj                        index        view
# 28876  0035hobuyj               search_results       click
# 28877  0035hobuyj                       lookup         NaN
# 28878  0035hobuyj               search_results       click
# 28879  0035hobuyj               search_results       click
# 28880  0035hobuyj                       lookup         NaN
# 28881  0035hobuyj               search_results       click
# 28882  0035hobuyj                       lookup         NaN
# 28883  0035hobuyj               search_results       click
#
#                      action_detail  device_type  secs_elapsed  \
# 28395                          NaN  Mac Desktop           429
# 28396          view_search_results  Mac Desktop          3196
# 28397                          NaN  Mac Desktop           865
# 28398          view_search_results  Mac Desktop         10726
# 28399                          NaN  Mac Desktop           357
# 28400          view_search_results  Mac Desktop          4931
# 28401                          NaN  Mac Desktop           417
# 28402          view_search_results  Mac Desktop         15315
# 28403                          NaN  Mac Desktop           470
# 28404          view_search_results  Mac Desktop          9420
# 28405                          NaN  Mac Desktop           413
# 28406          view_search_results  Mac Desktop          5208
# 28407                          NaN  Mac Desktop           364
# 28408          view_search_results  Mac Desktop         32247
# 28409                          NaN  Mac Desktop          2500
# 28410          view_search_results  Mac Desktop         25060
# 28411                          NaN  Mac Desktop           987
# 28412          view_search_results  Mac Desktop          1094
# 28413                          NaN  Mac Desktop           345
# 28414                           p3  Mac Desktop        100936
# 28415          view_search_results  Mac Desktop          1073
# 28416                          NaN  Mac Desktop           366
# 28417          view_search_results  Mac Desktop           805
# 28418          view_search_results  Mac Desktop          1673
# 28419                  create_user  Mac Desktop             0
# 28420               header_userpic  Mac Desktop           405
# 28421      wishlist_content_update  Mac Desktop           173
# 28422                    -unknown-  Mac Desktop         31418
# 28423          view_search_results  Mac Desktop          3549
# 28424          view_search_results  Mac Desktop          6782
# ...                            ...          ...           ...
# 28854                          NaN  Mac Desktop           753
# 28855          view_search_results  Mac Desktop           536
# 28856                          NaN  Mac Desktop           363
# 28857          view_search_results  Mac Desktop          1325
# 28858                          NaN  Mac Desktop           688
# 28859          view_search_results  Mac Desktop          7174
# 28860                          NaN  Mac Desktop           786
# 28861          view_search_results  Mac Desktop          1164
# 28862                          NaN  Mac Desktop           413
# 28863          view_search_results  Mac Desktop          3508
# 28864                          NaN  Mac Desktop           608
# 28865          view_search_results  Mac Desktop          1358
# 28866                          NaN  Mac Desktop           305
# 28867          view_search_results  Mac Desktop           730
# 28868                          NaN  Mac Desktop           427
# 28869                           p3  Mac Desktop         29102
# 28870      wishlist_content_update  Mac Desktop           734
# 28871                          NaN  Mac Desktop            61
# 28872                    -unknown-  Mac Desktop            40
# 28873  change_trip_characteristics  Mac Desktop          1165
# 28874             similar_listings  Mac Desktop           231
# 28875          view_search_results  Mac Desktop        168913
# 28876          view_search_results  Mac Desktop         13622
# 28877                          NaN  Mac Desktop           362
# 28878          view_search_results  Mac Desktop         57483
# 28879          view_search_results  Mac Desktop             0
# 28880                          NaN  Mac Desktop           342
# 28881          view_search_results  Mac Desktop         24655
# 28882                          NaN  Mac Desktop           340
# 28883          view_search_results  Mac Desktop          8607
#
#        minutes_elapsed  hours_elapsed  days_elapsed
# 28395                7            0.1           0.0
# 28396               53            0.9           0.0
# 28397               14            0.2           0.0
# 28398              179            3.0           0.1
# 28399                6            0.1           0.0
# 28400               82            1.4           0.1
# 28401                7            0.1           0.0
# 28402              255            4.3           0.2
# 28403                8            0.1           0.0
# 28404              157            2.6           0.1
# 28405                7            0.1           0.0
# 28406               87            1.4           0.1
# 28407                6            0.1           0.0
# 28408              537            9.0           0.4
# 28409               42            0.7           0.0
# 28410              418            7.0           0.3
# 28411               16            0.3           0.0
# 28412               18            0.3           0.0
# 28413                6            0.1           0.0
# 28414             1682           28.0           1.2
# 28415               18            0.3           0.0
# 28416                6            0.1           0.0
# 28417               13            0.2           0.0
# 28418               28            0.5           0.0
# 28419                0            0.0           0.0
# 28420                7            0.1           0.0
# 28421                3            0.0           0.0
# 28422              524            8.7           0.4
# 28423               59            1.0           0.0
# 28424              113            1.9           0.1
# ...                ...            ...           ...
# 28854               13            0.2           0.0
# 28855                9            0.1           0.0
# 28856                6            0.1           0.0
# 28857               22            0.4           0.0
# 28858               11            0.2           0.0
# 28859              120            2.0           0.1
# 28860               13            0.2           0.0
# 28861               19            0.3           0.0
# 28862                7            0.1           0.0
# 28863               58            1.0           0.0
# 28864               10            0.2           0.0
# 28865               23            0.4           0.0
# 28866                5            0.1           0.0
# 28867               12            0.2           0.0
# 28868                7            0.1           0.0
# 28869              485            8.1           0.3
# 28870               12            0.2           0.0
# 28871                1            0.0           0.0
# 28872                1            0.0           0.0
# 28873               19            0.3           0.0
# 28874                4            0.1           0.0
# 28875             2815           46.9           2.0
# 28876              227            3.8           0.2
# 28877                6            0.1           0.0
# 28878              958           16.0           0.7
# 28879                0            0.0           0.0
# 28880                6            0.1           0.0
# 28881              411            6.8           0.3
# 28882                6            0.1           0.0
# 28883              143            2.4           0.1
#
# [489 rows x 9 columns]

# %%
## Number of different devices used
user_af.loc[unique_ids[i],'num_device_types'] = len(np.unique(user['device_type'].values))


## Number of sessions
tbs = 10 # elapsed time defining new session
user_af.loc[unique_ids[i],'num_sessions'] = sum(user['hours_elapsed']>10)+1


## Number of different days
user_af.loc[unique_ids[i],'num_days_active'] = sum(user['days_elapsed']>=1)+1


### Time during sessions
tbs = 10
split_indices = user['hours_elapsed']>tbs
time_in_sessions = user[user['hours_elapsed']<=tbs]['secs_elapsed']

user_af.loc[unique_ids[i],'total_session_time '] = time_in_sessions.sum()

#Average and Max Session Times
B = np.split(time_in_sessions,np.where(split_indices)[0]) # Split all sessions into groups
session_times = [b.sum() for b in B]
print(session_times)
session_action_count = [len(b) for b in B]

user_af.loc[unique_ids[i],'avg_session_time'] = np.mean(session_times)
user_af.loc[unique_ids[i],'max_session_time'] = np.max(session_times)
user_af.loc[unique_ids[i],'max_session_action'] = np.max(session_action_count)
user_af.loc[unique_ids[i],'mean_session_action'] = np.mean(session_action_count)


## Average Time per Action, excluding large gaps
user_af.loc[unique_ids[i],'mean_secs_per_action'] = np.mean(user[user['secs_elapsed']<=3600]['secs_elapsed'])



### Time between sessions
time_between_sessions = user[user['hours_elapsed']>tbs]['secs_elapsed']

user_af.loc[unique_ids[i],'max_between_session'] = time_between_sessions.max()
user_af.loc[unique_ids[i],'mean_between_session'] = time_between_sessions.mean()
# Out:
# [114344.0, 68020.0, 52482.0, 106708.0, 4425.0, 30937.0, 43305.0, 18946.0, 693.0, 321.0, 31719.0, 17799.0, 48237.0, 210919.0, 101466.0, 8092.0, 32152.0, 62739.0, 44414.0, 15430.0, 445276.0, 41055.0, 622.0, 237965.0, 82689.0, 0, 0]

# %%
len(time_in_sessions)
# Out:
# 463

# %%
np.where(split_indices)[0]
# Out:
# array([ 19,  35,  44,  64,  69,  73,  98, 101, 103, 104, 110, 115, 123,
#        179, 219, 224, 231, 248, 261, 274, 369, 374, 375, 445, 480, 483], dtype=int64)

# %%
B[-1]
# Out:
# Series([], Name: secs_elapsed, dtype: float64)

# %%
session_times
# Out:
# [1927.4705882352941,
#  2360.102564102564,
#  2582.133333333333,
#  2946.9473684210525,
#  4291.55,
#  3484.8837209302324,
#  693.7272727272727,
#  1404.1052631578948,
#  3982.824324324324,
#  2561.777777777778,
#  2337.6,
#  5738.5,
#  170.5,
#  3705.5,
#  2739.5135135135133,
#  2977.8260869565215,
#  2158.3174603174602,
#  2632.5365853658536,
#  2020.7380952380952,
#  1062.25,
#  1698.8333333333333,
#  1906.076923076923,
#  2688.264150943396,
#  nan]

# %%
user_af.loc[unique_ids[6]]
# Out:
# num_device_types              1.000000
# num_sessions                 27.000000
# num_days_active              15.000000
# total_session_time      1820755.000000
# avg_session_time          67435.370370
# max_session_time         445276.000000
# max_session_action           95.000000
# mean_session_action          17.148148
# mean_secs_per_action        811.919444
# max_between_session     1215345.000000
# mean_between_session     150150.576923
# Name: 0035hobuyj, dtype: float64

# %%
user
# Out:
#             user_id               action action_type            action_detail  \
# 2864114  002qnbzfs5   social_connections        data  user_social_connections
# 2864115  002qnbzfs5      payment_methods   -unknown-                -unknown-
# 2864116  002qnbzfs5               create   -unknown-                -unknown-
# 2864117  002qnbzfs5                 show        view             user_profile
# 2864118  002qnbzfs5     unavailabilities        data        unavailable_dates
# 2864119  002qnbzfs5  payment_instruments        data      payment_instruments
# 2864120  002qnbzfs5                index        data             reservations
# 2864121  002qnbzfs5                index         NaN                      NaN
# 2864122  002qnbzfs5   social_connections        data  user_social_connections
# 2864123  002qnbzfs5             listings        view            user_listings
# 2864124  002qnbzfs5                index        view            message_inbox
# 2864125  002qnbzfs5               active   -unknown-                -unknown-
# 2864126  002qnbzfs5                 show        view                       p3
# 2864127  002qnbzfs5                 show        view             user_profile
# 2864128  002qnbzfs5               search       click      view_search_results
# 2864129  002qnbzfs5               search       click      view_search_results
# 2864130  002qnbzfs5                index         NaN                      NaN
# 2864131  002qnbzfs5            campaigns         NaN                      NaN
# 2864132  002qnbzfs5                index        view            message_inbox
# 2864133  002qnbzfs5                index         NaN                      NaN
# 2864134  002qnbzfs5                 show   -unknown-                -unknown-
# 2864135  002qnbzfs5                 show   -unknown-                -unknown-
# 2864136  002qnbzfs5                 show        view             user_profile
# 2864137  002qnbzfs5   social_connections        data  user_social_connections
# 2864138  002qnbzfs5                index        view            message_inbox
# 2864139  002qnbzfs5                index         NaN                      NaN
# 2864140  002qnbzfs5                 show   -unknown-                -unknown-
# 2864141  002qnbzfs5                 show   -unknown-                -unknown-
# 2864142  002qnbzfs5                 show        view             user_profile
# 2864143  002qnbzfs5   social_connections        data  user_social_connections
# ...             ...                  ...         ...                      ...
# 2864873  002qnbzfs5                 show        view                       p3
# 2864874  002qnbzfs5                 show        view             user_profile
# 2864875  002qnbzfs5                 show        view             user_profile
# 2864876  002qnbzfs5                index   -unknown-                -unknown-
# 2864877  002qnbzfs5             listings        view            user_listings
# 2864878  002qnbzfs5               active   -unknown-                -unknown-
# 2864879  002qnbzfs5            campaigns         NaN                      NaN
# 2864880  002qnbzfs5  payment_instruments        data      payment_instruments
# 2864881  002qnbzfs5                index        data             reservations
# 2864882  002qnbzfs5     unavailabilities        data        unavailable_dates
# 2864883  002qnbzfs5                 show        view             user_profile
# 2864884  002qnbzfs5   social_connections        data  user_social_connections
# 2864885  002qnbzfs5                 show        view             user_profile
# 2864886  002qnbzfs5  payment_instruments        data      payment_instruments
# 2864887  002qnbzfs5               create   -unknown-                -unknown-
# 2864888  002qnbzfs5      payment_methods   -unknown-                -unknown-
# 2864889  002qnbzfs5                click       click                  book_it
# 2864890  002qnbzfs5                 show   -unknown-                -unknown-
# 2864891  002qnbzfs5               active   -unknown-                -unknown-
# 2864892  002qnbzfs5            campaigns         NaN                      NaN
# 2864893  002qnbzfs5                click       click                  book_it
# 2864894  002qnbzfs5                 show   -unknown-                -unknown-
# 2864895  002qnbzfs5                 show        view             user_profile
# 2864896  002qnbzfs5   social_connections        data  user_social_connections
# 2864897  002qnbzfs5                index         NaN                      NaN
# 2864898  002qnbzfs5                 show        view             user_profile
# 2864899  002qnbzfs5   social_connections        data  user_social_connections
# 2864900  002qnbzfs5                 show        view                       p3
# 2864901  002qnbzfs5                 show        view             user_profile
# 2864902  002qnbzfs5   social_connections        data  user_social_connections
#
#         device_type  secs_elapsed  minutes_elapsed  hours_elapsed  \
# 2864114      iPhone         17135              286            4.8
# 2864115      iPhone           711               12            0.2
# 2864116      iPhone           274                5            0.1
# 2864117      iPhone           179                3            0.0
# 2864118      iPhone           483                8            0.1
# 2864119      iPhone             1                0            0.0
# 2864120      iPhone           782               13            0.2
# 2864121      iPhone          2300               38            0.6
# 2864122      iPhone           641               11            0.2
# 2864123      iPhone           236                4            0.1
# 2864124      iPhone             4                0            0.0
# 2864125      iPhone            28                0            0.0
# 2864126      iPhone            35                1            0.0
# 2864127      iPhone          3153               53            0.9
# 2864128      iPhone          1317               22            0.4
# 2864129      iPhone          5406               90            1.5
# 2864130      iPhone            82                1            0.0
# 2864131      iPhone        315547             5259           87.7
# 2864132      iPhone           144                2            0.0
# 2864133      iPhone          6747              112            1.9
# 2864134      iPhone           671               11            0.2
# 2864135      iPhone           111                2            0.0
# 2864136      iPhone            39                1            0.0
# 2864137      iPhone          4194               70            1.2
# 2864138      iPhone            92                2            0.0
# 2864139      iPhone          5719               95            1.6
# 2864140      iPhone           589               10            0.2
# 2864141      iPhone            78                1            0.0
# 2864142      iPhone            20                0            0.0
# 2864143      iPhone          5345               89            1.5
# ...             ...           ...              ...            ...
# 2864873      iPhone          1642               27            0.5
# 2864874      iPhone           492                8            0.1
# 2864875      iPhone            76                1            0.0
# 2864876      iPhone          7546              126            2.1
# 2864877      iPhone           335                6            0.1
# 2864878      iPhone           122                2            0.0
# 2864879      iPhone         17441              291            4.8
# 2864880      iPhone            86                1            0.0
# 2864881      iPhone            14                0            0.0
# 2864882      iPhone           203                3            0.1
# 2864883      iPhone           219                4            0.1
# 2864884      iPhone             5                0            0.0
# 2864885      iPhone           222                4            0.1
# 2864886      iPhone            59                1            0.0
# 2864887      iPhone           767               13            0.2
# 2864888      iPhone           497                8            0.1
# 2864889      iPhone          4452               74            1.2
# 2864890      iPhone            76                1            0.0
# 2864891      iPhone            97                2            0.0
# 2864892      iPhone        111413             1857           30.9
# 2864893      iPhone          6703              112            1.9
# 2864894      iPhone           310                5            0.1
# 2864895      iPhone            23                0            0.0
# 2864896      iPhone          3149               52            0.9
# 2864897      iPhone          4565               76            1.3
# 2864898      iPhone            19                0            0.0
# 2864899      iPhone           354                6            0.1
# 2864900      iPhone            75                1            0.0
# 2864901      iPhone             1                0            0.0
# 2864902      iPhone            15                0            0.0
#
#          days_elapsed
# 2864114           0.2
# 2864115           0.0
# 2864116           0.0
# 2864117           0.0
# 2864118           0.0
# 2864119           0.0
# 2864120           0.0
# 2864121           0.0
# 2864122           0.0
# 2864123           0.0
# 2864124           0.0
# 2864125           0.0
# 2864126           0.0
# 2864127           0.0
# 2864128           0.0
# 2864129           0.1
# 2864130           0.0
# 2864131           3.7
# 2864132           0.0
# 2864133           0.1
# 2864134           0.0
# 2864135           0.0
# 2864136           0.0
# 2864137           0.0
# 2864138           0.0
# 2864139           0.1
# 2864140           0.0
# 2864141           0.0
# 2864142           0.0
# 2864143           0.1
# ...               ...
# 2864873           0.0
# 2864874           0.0
# 2864875           0.0
# 2864876           0.1
# 2864877           0.0
# 2864878           0.0
# 2864879           0.2
# 2864880           0.0
# 2864881           0.0
# 2864882           0.0
# 2864883           0.0
# 2864884           0.0
# 2864885           0.0
# 2864886           0.0
# 2864887           0.0
# 2864888           0.0
# 2864889           0.1
# 2864890           0.0
# 2864891           0.0
# 2864892           1.3
# 2864893           0.1
# 2864894           0.0
# 2864895           0.0
# 2864896           0.0
# 2864897           0.1
# 2864898           0.0
# 2864899           0.0
# 2864900           0.0
# 2864901           0.0
# 2864902           0.0
#
# [789 rows x 9 columns]

# %%
user = session_df[session_df['user_id']== '002qnbzfs5']
any(user['secs_elapsed'].isnull())
# Out:
# False

# %%
unique_ids[4]
# Out:
# '002qnbzfs5'

# %%
user_af1 = user_af

# %% [markdown]
# X = user_af.dropna()

# %%
X = pd.merge(user_af.dropna(),train_users[['id','country_destination']],how='inner',left_index=True,right_on='id').drop('id',axis=1)

# %%
X
# Out:
#         num_device_types  num_sessions  num_days_active  total_session_time   \
# 189274                 2             4                3               127804
# 179944                 1             2                1               232417
# 208158                 2             3                2               165126
# 174809                 1            15                5               670035
# 153845                 1             2                2                72261
# 205080                 1             4                2               268857
# 200100                 1             7                5               239518
# 199579                 1             7                4               116867
# 193309                 1             2                1                22645
# 145362                 1             2                1               176274
# 141954                 1             3                2               358713
# 182792                 1             4                2                98835
# 139195                 1             2                2                53865
# 167925                 1             7                3               586754
# 189175                 1             5                2               115473
# 155972                 1             2                2                25878
# 201435                 1             4                1                53230
# 163151                 1             5                5                29200
# 137264                 1             7                2                52410
# 174809         125302.357143                  ES
# 153845         298145.000000                  US
# 205080          75779.666667                 NDF
# 200100         108248.500000                  US
# 199579         132755.500000                 NDF
# 193309          52923.000000                  US
# 145362          44813.000000                 NDF
# 141954          76400.500000                 NDF
# 182792          68349.666667                 NDF
# 139195         223215.000000                 NDF
# 167925         100368.000000                  IT
# 189175          64415.500000                  US
# 155972         137815.000000                 NDF
# 201435          56672.333333                 NDF
# 163151         441950.000000                  FR
# 137264          81044.000000                  US
# 166028          42465.000000                 NDF
# 140935          89128.333333                 NDF
# 183623         249894.400000                  FR
# 145317         115103.857143                  DE
# 192209         242532.000000                 NDF
# 213374         406517.000000                 NDF
# 145035         150258.800000                 NDF
# 142595          90615.500000                 NDF
# 175255         164782.500000                 NDF
# 155448          97407.500000                  US
# 190524         538756.000000                  US
# ...                      ...                 ...
# 186106         814900.000000                  US
# 205711         203538.000000                 NDF
# 140350          41469.000000                 NDF
# 141526         160127.000000                 NDF
# 198322         155543.750000                  US
# 179592          89870.000000                 NDF
# 138511          60699.333333                  US
# 137570         131071.000000                 NDF
# 162004          57617.200000                 NDF
# 181909         160002.769231                 NDF
# 197959          77730.000000                 NDF
# 209646         118062.000000                 NDF
# 140014         165745.428571                 NDF
# 180902         232945.000000                 NDF
# 209289         102140.800000                 NDF
# 158897          47131.000000                 NDF
# 172927          43397.000000                 NDF
# 184150         994345.000000                 NDF
# 147472         276862.500000                 NDF
# 156366         709971.500000                 NDF
# 165621          73216.000000                  US
# 207890          40866.500000                 NDF
# 202749         205009.000000                 NDF
# 208680          70395.200000                 NDF
# 199997         115897.000000                  US
# 201042          78984.000000                 NDF
# 178854        1393746.000000                 NDF
# 178587          36416.000000                 NDF
# 161996         258834.666667                 NDF
# 201516         102036.090909                 NDF
#
# [503 rows x 12 columns]

# %%
y = X['country_destination']!='NDF'
y
# Out:
# 189274     True
# 179944    False
# 208158    False
# 174809     True
# 153845     True
# 205080    False
# 200100     True
# 199579    False
# 193309     True
# 145362    False
# 141954    False
# 182792    False
# 139195    False
# 167925     True
# 189175     True
# 155972    False
# 201435    False
# 163151     True
# 137264     True
# 166028    False
# 140935    False
# 183623     True
# 145317     True
# 192209    False
# 213374    False
# 145035    False
# 142595    False
# 175255    False
# 155448     True
# 190524     True
#           ...
# 186106     True
# 205711    False
# 140350    False
# 141526    False
# 198322     True
# 179592    False
# 138511     True
# 137570    False
# 162004    False
# 181909    False
# 197959    False
# 209646    False
# 140014    False
# 180902    False
# 209289    False
# 158897    False
# 172927    False
# 184150    False
# 147472    False
# 156366    False
# 165621     True
# 207890    False
# 202749    False
# 208680    False
# 199997     True
# 201042    False
# 178854    False
# 178587    False
# 161996    False
# 201516    False
# Name: country_destination, dtype: bool

# %%
user_af1
# Out:
#             num_device_types  num_sessions  num_days_active  \
# 00023iyk9l                 2             4                3
# 0010k6l0om                 1             6                3
# 001wyh0pz8                 1             2                1
# 0028jgx1x1                 2             3                2
# 002qnbzfs5                 2            24               15
# 0031awlkjq                 1             1                1
# 0035hobuyj                 1            27               15
# 00378ocvlh                 1             8                5
# 00389675gq                 2            21               10
# 003iamz20l                 1            15                3
# 0048rkdgb1                 1             3                2
# 0057snrdpu                 2             5                2
# 005jc3nbmb                 2             6                4
# 005v5uf4dh                 1             2                1
# 0063bawn05                 1             8                6
# 006ml14zc1                 1             3                1
# 006mls2sjw                 1            15                5
# 006t3vhawl                 1             9                6
# 006z8b0uws                 2             3                2
# 0075z9e9xv                 2            15                6
# 007gj7kqdk                 1             2                2
# 009a40t3dk                 3             7                4
# 00a8dbifj8                 1             4                2
# 00allnceb8                 1             1                1
# 00an0o6c07                 2             4                3
# 00b9hfwaak                 1             7                5
# 00bn6hu437                 1             7                4
# 00bowi9sn3                 1             2                1
# 00bqkh0g5i                 1             1                1
# 00bxmflswn                 2            16                7
# ...                      ...           ...              ...
# zzq90ckj2z               NaN           NaN              NaN
# zzqb2sn066               NaN           NaN              NaN
# zzr1rkdsh9               NaN           NaN              NaN
# zzrnx9rqi5               NaN           NaN              NaN
# zzsoxtv8zb               NaN           NaN              NaN
# zzsslqqkee               NaN           NaN              NaN
# zzsszlux3t               NaN           NaN              NaN
# zzswqjsqy4               NaN           NaN              NaN
# zzt5gpsyqa               NaN           NaN              NaN
# zzt8w28nl5               NaN           NaN              NaN
# zztaeo9wd5               NaN           NaN              NaN
# zztkv1gkse               NaN           NaN              NaN
# zzu3u71odh               NaN           NaN              NaN
# zzu6ezwap2               NaN           NaN              NaN
# zzunwylrfv               NaN           NaN              NaN
# zzuy4rvdki               NaN           NaN              NaN
# zzv6z6rjr9               NaN           NaN              NaN
# zzv8sgicbk               NaN           NaN              NaN
# zzvatt4dio               NaN           NaN              NaN
# zzvg4emw5w               NaN           NaN              NaN
# zzvr84im58               NaN           NaN              NaN
# zzw7kydxfa               NaN           NaN              NaN
# zzx06inhbv               NaN           NaN              NaN
# zzx0hfd74v               NaN           NaN              NaN
# zzx5wp3lqu               NaN           NaN              NaN
# zzxox7jnrx               NaN           NaN              NaN
# zzy7t0y9cm               NaN           NaN              NaN
# zzysuoqg6x               NaN           NaN              NaN
# zzywmcn0jv               NaN           NaN              NaN
# zzzlylp57e               NaN           NaN              NaN
#
#             total_session_time   avg_session_time  max_session_time  \
# 00023iyk9l               127804       3258.666667       4713.111111
# 0010k6l0om               210700       2816.267983       5707.291667
# 001wyh0pz8               232417       2825.486307       3184.944444
# 0028jgx1x1               165126       5880.275000       6825.200000
# 002qnbzfs5              2128886               NaN               NaN
# 0031awlkjq                39574       4946.750000       4946.750000
# 0035hobuyj              1820755               NaN               NaN
# 00378ocvlh               344277               NaN               NaN
# 00389675gq               588327               NaN               NaN
# 003iamz20l               535816               NaN               NaN
# 0048rkdgb1               198596       3424.794118       6895.882353
# 0057snrdpu               154545               NaN               NaN
# 005jc3nbmb               112563               NaN               NaN
# 005v5uf4dh               124969       1886.794118       3672.588235
# 0063bawn05               264234       5719.084201      13642.000000
# 006ml14zc1                89902       2084.397619       3553.050000
# 006mls2sjw               670035       2128.954878       5257.684211
# 006t3vhawl                85304               NaN               NaN
# 00bn6hu437               253312         132755.500000
# 00bowi9sn3                52923          52923.000000
# 00bqkh0g5i                  NaN                   NaN
# 00bxmflswn              1307338         207034.800000
# ...                         ...                   ...
# zzq90ckj2z                  NaN                   NaN
# zzqb2sn066                  NaN                   NaN
# zzr1rkdsh9                  NaN                   NaN
# zzrnx9rqi5                  NaN                   NaN
# zzsoxtv8zb                  NaN                   NaN
# zzsslqqkee                  NaN                   NaN
# zzsszlux3t                  NaN                   NaN
# zzswqjsqy4                  NaN                   NaN
# zzt5gpsyqa                  NaN                   NaN
# zzt8w28nl5                  NaN                   NaN
# zztaeo9wd5                  NaN                   NaN
# zztkv1gkse                  NaN                   NaN
# zzu3u71odh                  NaN                   NaN
# zzu6ezwap2                  NaN                   NaN
# zzunwylrfv                  NaN                   NaN
# zzuy4rvdki                  NaN                   NaN
# zzv6z6rjr9                  NaN                   NaN
# zzv8sgicbk                  NaN                   NaN
# zzvatt4dio                  NaN                   NaN
# zzvg4emw5w                  NaN                   NaN
# zzvr84im58                  NaN                   NaN
# zzw7kydxfa                  NaN                   NaN
# zzx06inhbv                  NaN                   NaN
# zzx0hfd74v                  NaN                   NaN
# zzx5wp3lqu                  NaN                   NaN
# zzxox7jnrx                  NaN                   NaN
# zzy7t0y9cm                  NaN                   NaN
# zzysuoqg6x                  NaN                   NaN
# zzywmcn0jv                  NaN                   NaN
# zzzlylp57e                  NaN                   NaN
#
# [135483 rows x 11 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score


RF = RandomForestClassifier(oob_score=True,n_estimators=200,class_weight='balanced')
CV_score = cross_val_score(RF,X,y,scoring='accuracy', cv=5, verbose=1)
print('CV scores = ',CV_score)
print('Mean CV score = ', np.mean(CV_score))
# Out:
# CV scores =  [ 0.62745098  0.68316832  0.64        0.63        0.61      ]
# Mean CV score =  0.638123859445
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.2s finished

# %%
1 - sum(y)/len(y)
# Out:
# 0.6500994035785288

# %%
from sklearn.feature_selection import SelectKBest

selector = SelectKBest(k=10)

# %%
X_new = selector.fit_transform(X,y)

FeaturePvalues = pd.Series(index=X.columns,data=selector.pvalues_).sort_values(ascending=True)
FeatureScores = pd.Series(index=X.columns,data=selector.scores_).sort_values(ascending=False)

# %%
k = 10
plt.figure(figsize=(10,15))
sns.barplot(y=FeatureScores.index[0:k],x=FeatureScores.head(k))
#plt.xticks(rotation = 90)
# Out:
# c:\Anaconda3\lib\site-packages\matplotlib\__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
X.drop('country_destination',axis=1,inplace=True)

# %%
y.shape
# Out:
# (503,)

# %%
train_users.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender  age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-  NaN      facebook            0       en            direct
# 1       MALE   38      facebook            0       en               seo
# 2     FEMALE   56         basic            3       en            direct
# 3     FEMALE   42      facebook            0       en            direct
# 4  -unknown-   41         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
user['minutes_elapsed']=user['secs_elapsed']/60
user['hours_elapsed']=user['secs_elapsed']/3600
user['days_elapsed']=user['secs_elapsed']/(3600*24)
# Out:
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# c:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
user['num_sesso']

# %%
#np.sum
(user[user['hours_elapsed']<=2]['minutes_elapsed'])
# Out:
# 7531832    28.466667
# 7531834    20.383333
# 7531835     0.433333
# 7531836    14.116667
# 7531837    20.500000
# 7531838     2.483333
# 7531839     9.750000
# 7531840    14.083333
# 7531841     0.000000
# 7531842     0.366667
# 7531844     0.500000
# 7531845    11.233333
# 7531846     2.950000
# 7531847     0.816667
# 7531850     2.950000
# 7531852    72.316667
# 7531853     2.083333
# 7531854     2.083333
# 7531857    12.000000
# 7531858    14.116667
# 7531860    20.416667
# 7531861     0.600000
# 7531862    28.766667
# 7531863     4.050000
# 7531864     0.566667
# 7531867    17.500000
# 7531868     0.750000
# 7531869    25.516667
# 7531870     2.833333
# 7531871     0.883333
# 7531873    18.016667
# 7531874     1.383333
# 7531875    37.050000
# 7531876     1.700000
# 7531877     1.516667
# 7531880    18.416667
# 7531881     1.800000
# 7531882    38.233333
# 7531883     3.200000
# 7531884     0.150000
# 7531885    54.866667
# 7531887    22.650000
# 7531888     0.650000
# 7531889    33.216667
# 7531890     2.983333
# 7531891     0.766667
# 7531892     0.050000
# 7531894    44.566667
# Name: minutes_elapsed, dtype: float64

# %%
user_af.loc[unique_ids[1],'avg_session_time'] = np.mean(user[user['hours_elapsed']>10]['hours_elapsed'])
# Out:
# 20.880166666666668

# %%
user_af.loc[unique_ids[1],'num_sessions'] = sum(user['hours_elapsed']>10) + 1

user_af.loc[unique_ids[1],'avg_time_between_sessions'] = np.mean(user[user['hours_elapsed']>10]['hours_elapsed'])

user_af.loc[unique_ids[1],'avg_session_time'] = np.mean(user[user['hours_elapsed']>10]['hours_elapsed'])


user_af.loc[unique_ids[1],'num_days'] = sum(user['days_elapsed']>1)

user_af.loc[unique_ids[1]]
# Out:
# num_sessions                5.000000
# num_days                    2.000000
# num_separate_days_active    6.788692
# Name: 0010k6l0om, dtype: float64

# %%
# Out:
# num_sessions                6.000000
# num_days                    6.788692
# num_separate_days_active    6.788692
# Name: 0010k6l0om, dtype: float64

# %%
#Number of days since first active

# %%
X = pd.merge(airbnb_df,session_grouped,left_on='id',right_index=True,how='inner')
X.info()

# %%
Y = pd.merge(test_df,session_grouped,left_on='id',right_index=True,how='inner')
Y.info()

# %%
X.head()

# %%
X['booked'] = X['country_destination']!='NDF'
sns.violinplot(data = X[X['action']<200], y = 'action',x = 'booked')
plt.xlabel('number of actions')

# %%
X['booked'] = X['country_destination']!='NDF'
sns.violinplot(data = X[X['secs_elapsed']<1e7], y = 'secs_elapsed',x = 'booked')
plt.xlabel('number of actions')

# %%
plt.scatter(X['booked'],X['secs_elapsed'],alpha=0.5)

# %%
plt.scatter(X['action'],X['secs_elapsed'],c=X['booked'])
plt.legend(['No booking','Booked'])

# %%
sns.distplot(X['action'],c=)

# %%
fig,ax = plt.subplots(figsize=(8,5))
sns.distplot(X[X['booked']==True]['secs_elapsed'],hist_kws={"normed":1})
sns.distplot(X[X['booked']==False]['secs_elapsed'],color='y',hist_kws={"normed":1})

# %%
print(sum(X['booked']))
len(X)

# %%
session_df.columns

# %%
A = session_df.groupby(['action','action_type']).count()['user_id'].sort_values(ascending=False)
A

# %%
print(len(A[A>100]))
print(A[A>100])
